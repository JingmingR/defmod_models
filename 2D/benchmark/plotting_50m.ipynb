# %%
# %matplotlib widget
# %load_ext autoreload
# %autoreload 2
import numpy as np
import h5py
import os, sys
sys.path.append('/home/jingmingruan/ownCloud/dataprocessing')
# sys.path.append('/home/jingmingruan/TUD/DeepNL/cloud/dataprocessing')
from plot_2D import *

# %%
# %run /home/jingmingruan/ownCloud/dataprocessing/fe_sort.py -f ./run01/Zeerijp -dmn 3 -slip 1 -dyn 0 -rsf 0 -poro 1 -nobs 0
# %run /home/jingmingruan/ownCloud/dataprocessing/fe_sort.py -f ./run01/Zeerijp -dmn 3 -slip 1 -dyn 0 -rsf 0 -poro 1 -nobs 0

# %%
dyn= 1
Zeerijp = plot2D("./Buijze_benchmark_06m_fe.h5",dyn=dyn,seis=0)
# Zeerijp = plot2D("./Buijze_benchmark_50m_fe.h5",dyn=dyn,seis=0)
# Zeerijp_ = plot2D("./Buijze_benchmark_initsigmay_fe.h5",dyn=0)

step_list = [4,8,12,15]
step_ = [15]
vline = 0.8
axis = 1
mask = 0.
delta = 0
projection=False

# %%
if dyn: 
    print (Zeerijp.dat_log)
    print (Zeerijp.dat_log_dyn)
    print (Zeerijp.dt_dyn)
# Out:
# [[23  0]
#  [24  0]
#  [25  0]
#  [26  0]
#  [27  0]
#  [28  0]
#  [29  0]
#  [30  1]
#  [35  0]]
# [ 201  401  601  801 1001 1201 1401 1601]
# 0.01

# %%
font = {'family' : 'serif',
        'size'   : 19}
# plt.style.use('seaborn-pastel') 
matplotlib.rc('font', **font)
# matplotlib.rc('image', cmap='jet') # not jet for 2D
# https://matplotlib.org/stable/tutorials/colors/colormaps.html

# %%
Zeerijp.plot_static_group(delta=0, benchmark=1,mask=0,zlim0=-3.2,zlim1=-2.7)

# %%
Zeerijp.plot_static_group(tstep_list=step_list,delta=0, benchmark=1,mask=0,zlim0=-3.1,zlim1=-2.7)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5411/389331222.py in <module>
# ----> 1 Zeerijp.plot_static_group(tstep_list=step_list,delta=0, benchmark=1,mask=0,zlim0=-3.1,zlim1=-2.7)
#
# TypeError: plot_static_group() got an unexpected keyword argument 'tstep_list'

# %%
Zeerijp.plot_static_group(tstep_list=step_list,delta=0, benchmark=1,mask=0,zlim0=-3.1,zlim1=-2.7)
# Out:
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['normal'] not found. Falling back to DejaVu Sans.

# %%
if dyn: 
    # print (Zeerijp.dat_trac_sort['step '+ str(27)].shape)
    t0 = 0
    t1 = 30
    dt = 5
    step = 15
    dyn_axis = 0
    dyn_steps = (np.arange(t0,t1,dt,dtype=np.int32))
    Zeerijp.plot_dyn_list2D(step,dyn_steps,dyn_axis,delta=False,
                     mask=0,zlim0=-3.5,zlim1=-2.6,
                     xlim0=-0.01,xlim1=0.11)

# %%
Zeerijp.plot_static_list2D(tstep_list=step_list, axis=2, delta=1, mask=0,zlim0=-3.1,zlim1=-2.7,punique=0)
# Out:
# 0.0
# 4.0000000000000036
# 7.9999999999999964
# 10.999999999999996

# %%
Zeerijp.plot_static_list2D(tstep_list=step_list, axis=2, delta=0, mask=0,zlim0=-3.1,zlim1=-2.7,punique=0)

# %%
Zeerijp.plot_static_list2D(tstep_list=step_list, axis=0, delta=delta, mask=0,zlim0=-3.1,zlim1=-2.7,punique=0)

# %%
Zeerijp.plot_static_list2D(tstep_list=step_list, axis=1, delta=0, mask=0,zlim0=-3.1,zlim1=-2.7,punique=0)

# %%
Zeerijp.plot_static_list2D(tstep_list=step_list, axis=3, delta=delta, mask=0,zlim0=-3.1,zlim1=-2.7,punique=0)

# %%
Zeerijp.plot_static_list2D(tstep_list=step_list, axis=4, delta=delta, mask=0,zlim0=-3.1,zlim1=-2.7,xlim0=0,xlim1=2.0,punique=0)

# %%
Zeerijp.plot_static_list2D(tstep_list=step_list, axis=4, delta=delta, mask=0,zlim0=-1.2,zlim1=-5.0,xlim0=0,xlim1=2.0,punique=0)
