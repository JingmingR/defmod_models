# %%
# ------------------------------------------------------------------------------
#
#  GMSH-CAD Groningen model desgin 
#
#  STEP import and manipulation, geometry partitioning
#
# ------------------------------------------------------------------------------

# %%
import gmsh
import math
import os
import sys
import numpy as np

# %%
def readfault(file,xmin=0,ymin=0,zmin=0):
    ps = []
    with codecs.open(file, encoding='utf-8-sig') as f:
        X = np.loadtxt(f)
    X[:,0] = X[:,0] - xmin
    X[:,1] = X[:,1] - ymin
    X[:,2] = X[:,2] - zmin
    for x in X[:]:
        ps.append(gmsh.model.occ.addPoint(float(x[0]), float(x[1]), float(x[2])))
    return ps

# %%
gmsh.initialize()
gmsh.model.add("spline")

# %%
import numpy as np
import codecs

with codecs.open('f1.txt', encoding='utf-8-sig') as f:
    X = np.loadtxt(f)
    
xmin, ymin, zmin, xmax, ymax, zmax = np.min(X[:,0]),np.min(X[:,1]),np.min(X[:,2]),np.max(X[:,0]),np.max(X[:,1]),np.max(X[:,1])

# %%
# read fault
ps1 = readfault("faults/M1.txt")
ps2 = readfault("faults/mFS7_Fault_52.txt")
ps3 = readfault("faults/mFS7_Fault_53.txt") # down
# ps3 = readfault("faults/f53_meger_LSSB.txt")
ps4 = readfault("faults/f54_1.txt") # left
ps5 = readfault("faults/f54_2.txt") # right
ps6 = readfault("faults/f38_1.txt")
ps7 = readfault("faults/f38_2.txt")
ps8 = readfault("faults/f38_3.txt")
ps9 = readfault("faults/fm69_1.txt")
ps10 = readfault("faults/fm69_2.txt")
ps11 = readfault("faults/fm69_3.txt")

ps12 = readfault("faults/f54_ex.txt")
ps13 = readfault("faults/f54_ex2.txt")
ps14 = readfault("faults/extend_f54_2_xflt.txt")

f1 = gmsh.model.occ.addBSplineSurface(ps1, numPointsU=len(ps1)//10)
f2 = gmsh.model.occ.addBSplineSurface(ps2, numPointsU=len(ps2)//10)
f3 = gmsh.model.occ.addBSplineSurface(ps3, numPointsU=len(ps3)//10)
f4 = gmsh.model.occ.addBSplineSurface(ps4, numPointsU=len(ps4)//10)
f5 = gmsh.model.occ.addBSplineSurface(ps5, numPointsU=len(ps5)//10)
f6 = gmsh.model.occ.addBSplineSurface(ps6, numPointsU=len(ps6)//10)
f7 = gmsh.model.occ.addBSplineSurface(ps7, numPointsU=len(ps7)//10)
f8 = gmsh.model.occ.addBSplineSurface(ps8, numPointsU=len(ps8)//10)
f9 = gmsh.model.occ.addBSplineSurface(ps9, numPointsU=len(ps9)//10)
f10 = gmsh.model.occ.addBSplineSurface(ps10, numPointsU=len(ps10)//10)
f11 = gmsh.model.occ.addBSplineSurface(ps11, numPointsU=len(ps11)//10)
f12 = gmsh.model.occ.addBSplineSurface(ps12, numPointsU=len(ps12)//10)
f13 = gmsh.model.occ.addBSplineSurface(ps13, numPointsU=len(ps13)//10)
f14 = gmsh.model.occ.addBSplineSurface(ps14, numPointsU=len(ps14)//10)


gmsh.model.occ.synchronize()
gmsh.model.occ.removeAllDuplicates()

# %%
# manually
box = gmsh.model.occ.addBox(245317-1000+180, 597601-1000-180, -2350, 2000, 2000, -1000)
gmsh.model.occ.rotate([(3,box)], x=245317+180, y=597601-180, z=-5350, ax=0, ay=0, az=4000, angle=-30/180*np.pi)

gmsh.model.occ.fragment(gmsh.model.occ.getEntities(3),
                            gmsh.model.occ.getEntities(2))
gmsh.model.occ.synchronize()
# Out:
# Info    : Recomputing incorrect OpenCASCADE wire in surface 69

# %%
# zero-offset modelling
s3 = gmsh.model.occ.importShapes('surfaces/LSSB3.step')
s4 = gmsh.model.occ.importShapes('surfaces/LSSB4.step')
t3 = gmsh.model.occ.importShapes('surfaces/ROT3.step')
t4 = gmsh.model.occ.importShapes('surfaces/ROT4.step')
gmsh.model.occ.translate(s4, -0.20199935999698937, -0.15324089373461902, 6.754887411052096) # manually
gmsh.model.occ.translate(t4, -0.5888777230575215, -0.4467348244506866, 19.69216558035623) # manually

at3 = gmsh.model.occ.importShapes('surfaces/ROT3.step')
at4 = gmsh.model.occ.importShapes('surfaces/ROT4.step')
gmsh.model.occ.translate(at4, -0.5888777230575215-0.00293468, -0.4467348244506866-0.00222631, 69.69216558035623+0.09813601) # manually
gmsh.model.occ.translate(at3,0, 0, 50)
# gmsh.model.getValue(0,6041,[])-gmsh.model.getValue(0,6009,[])

gmsh.model.occ.synchronize()
gmsh.model.occ.fragment([(3,3)], [s3[0],t3[0],at3[0]],removeObject=True, removeTool=True)
gmsh.model.occ.fragment([(3,5)], [s4[0],t4[0],at4[0]],removeObject=True, removeTool=True)
# gmsh.model.occ.remove(s3, recursive=True)
# gmsh.model.occ.remove(s4, recursive=True)
gmsh.model.occ.remove(gmsh.model.occ.getEntities(2),recursive=True)
gmsh.model.occ.remove(gmsh.model.occ.getEntities(1),recursive=True)
gmsh.model.occ.remove(gmsh.model.occ.getEntities(0),recursive=True)

# np1 = gmsh.model.occ.addPoint(246317, 596601, -3143) # manually
# np2 = gmsh.model.occ.addPoint(246317, 596601, -2866) # manually
# np3 = gmsh.model.occ.addPoint(246317, 596601, -2866+50) # manually

gmsh.model.occ.synchronize()
gmsh.model.occ.removeAllDuplicates()
# Out:
# Info    :  - Label 'Shapes/Surface001' (2D)
# Info    :  - Label 'Shapes/Surface002' (2D)
# Info    :  - Label 'Shapes/Surface011' (2D)
# Info    :  - Label 'Shapes/Surface011' (2D)
# Info    :  - Label 'Shapes/Surface011' (2D)
# Info    :  - Label 'Shapes/Surface011' (2D)

# %%
# manually setting a extra zone for zero-offset tip

# exl1 = gmsh.model.occ.addLine(6051,np1)
# exl2 = gmsh.model.occ.addLine(np1,6056)
# exl3 = gmsh.model.occ.addLine(6053,np2)
# exl4 = gmsh.model.occ.addLine(np2,6057)

exl1 = gmsh.model.occ.addLine(6104,6109)
exl2 = gmsh.model.occ.addLine(6102,6108)
exl3 = gmsh.model.occ.addLine(6100,6107)



gmsh.model.occ.addCurveLoop([338,exl1,-350], 1)
s111 = gmsh.model.occ.addSurfaceFilling(1, tag=-1) 
gmsh.model.occ.addCurveLoop([335,exl2,-349], 2)
s222 = gmsh.model.occ.addSurfaceFilling(2, tag=-1) 
gmsh.model.occ.addCurveLoop([332,exl3,-348], 3)
s333 = gmsh.model.occ.addSurfaceFilling(3, tag=-1) 

gmsh.model.occ.fragment([(3,6)], [(2,s111),(2,s222),(2,s333)],removeObject=True, removeTool=True)
gmsh.model.occ.synchronize()
# Out:
# Info    : Recomputing incorrect OpenCASCADE wire in surface 144
# Info    : Recomputing incorrect OpenCASCADE wire in surface 147
# Info    : Recomputing incorrect OpenCASCADE wire in surface 148
# Info    : Recomputing incorrect OpenCASCADE wire in surface 158
# Info    : Recomputing incorrect OpenCASCADE wire in surface 172
# Info    : Recomputing incorrect OpenCASCADE wire in surface 176
# Info    : Recomputing incorrect OpenCASCADE wire in surface 196
# Info    : Recomputing incorrect OpenCASCADE wire in surface 198
# Info    : Recomputing incorrect OpenCASCADE wire in surface 201
# Info    : Recomputing incorrect OpenCASCADE wire in surface 203
# Info    : Recomputing incorrect OpenCASCADE wire in surface 206
# Info    : Recomputing incorrect OpenCASCADE wire in surface 208
# Info    : Recomputing incorrect OpenCASCADE wire in surface 212

# %%
# horizon modelling
s1 = gmsh.model.occ.importShapes('surfaces/LSSB1.step')
s2 = gmsh.model.occ.importShapes('surfaces/LSSB2.step')
s5 = gmsh.model.occ.importShapes('surfaces/LSSB5.step')
s6 = gmsh.model.occ.importShapes('surfaces/LSSB6.step')
t1 = gmsh.model.occ.importShapes('surfaces/ROT1.step')
t2 = gmsh.model.occ.importShapes('surfaces/ROT2.step')
t5 = gmsh.model.occ.importShapes('surfaces/ROT5.step')
t6 = gmsh.model.occ.importShapes('surfaces/ROT6.step')

# anhydrite
at1 = gmsh.model.occ.importShapes('surfaces/ROT1.step')
at2 = gmsh.model.occ.importShapes('surfaces/ROT2.step')
at5 = gmsh.model.occ.importShapes('surfaces/ROT5.step')
at6 = gmsh.model.occ.importShapes('surfaces/ROT6.step')
gmsh.model.occ.translate(at1,0, 0, 50)
gmsh.model.occ.translate(at2,0, 0, 50)
gmsh.model.occ.translate(at5,0, 0, 50)
gmsh.model.occ.translate(at6,0, 0, 50)
# Out:
# Info    :  - Label 'Shapes/Surface003' (2D)
# Info    :  - Label 'Shapes/Surface011' (2D)
# Info    :  - Label 'Shapes/Surface011' (2D)
# Info    :  - Label 'Shapes/Surface011' (2D)
# Info    :  - Label 'Shapes/Surface011' (2D)
# Info    :  - Label 'Shapes/Surface011' (2D)
# Info    :  - Label 'Shapes/Surface011' (2D)
# Info    :  - Label 'Shapes/Surface011' (2D)
# Info    :  - Label 'Shapes/Surface011' (2D)
# Info    :  - Label 'Shapes/Surface011' (2D)
# Info    :  - Label 'Shapes/Surface011' (2D)
# Info    :  - Label 'Shapes/Surface011' (2D)

# %%
gmsh.model.occ.fragment([(3,7)], [s1[0],t1[0],at1[0]],removeObject=True, removeTool=True)
gmsh.model.occ.fragment([(3,2)], [s2[0],t2[0],at2[0]],removeObject=True, removeTool=True)
gmsh.model.occ.fragment([(3,1)], [s5[0],t5[0],at5[0]],removeObject=True, removeTool=True)
gmsh.model.occ.fragment([(3,4)], [s6[0],t6[0],at6[0]],removeObject=True, removeTool=True)
# gmsh.model.occ.remove(s1, recursive=True)
# gmsh.model.occ.remove(s2, recursive=True)
# gmsh.model.occ.remove(s5, recursive=True)
# gmsh.model.occ.remove(s6, recursive=True)
gmsh.model.occ.remove(gmsh.model.occ.getEntities(2),recursive=True)
gmsh.model.occ.remove(gmsh.model.occ.getEntities(1),recursive=True)
gmsh.model.occ.remove(gmsh.model.occ.getEntities(0),recursive=True)
gmsh.model.occ.removeAllDuplicates()
gmsh.model.occ.synchronize()
# Out:
# Info    : Recomputing incorrect OpenCASCADE wire in surface 356
# Info    : Recomputing incorrect OpenCASCADE wire in surface 358
# Info    : Recomputing incorrect OpenCASCADE wire in surface 362
# Info    : Recomputing incorrect OpenCASCADE wire in surface 366
# Info    : Recomputing incorrect OpenCASCADE wire in surface 375
# Info    : Recomputing incorrect OpenCASCADE wire in surface 378
# Info    : Recomputing incorrect OpenCASCADE wire in surface 381
# Info    : Recomputing incorrect OpenCASCADE wire in surface 382
# Info    : Recomputing incorrect OpenCASCADE wire in surface 385

# %%
# Manual
# point 6246,6245,6165,6231
cp1 = (gmsh.model.getValue(0,6279,[])+gmsh.model.getValue(0,6277,[]))/2
cp2 = (gmsh.model.getValue(0,6277,[])+gmsh.model.getValue(0,6197,[]))/2
cp3 = (gmsh.model.getValue(0,6197,[])+gmsh.model.getValue(0,6263,[]))/2
cp4 = (gmsh.model.getValue(0,6263,[])+gmsh.model.getValue(0,6279,[]))/2

# %%
tp5 = gmsh.model.occ.addPoint(cp1[0],cp1[1],cp1[2])
tp6 = gmsh.model.occ.addPoint(cp2[0],cp2[1],cp2[2])
tp7 = gmsh.model.occ.addPoint(cp3[0],cp3[1],cp3[2])
tp8 = gmsh.model.occ.addPoint(cp4[0],cp4[1],cp4[2])

gmsh.model.occ.fragment(gmsh.model.occ.getEntities(3),[(0,tp5),(0,tp6),(0,tp7),(0,tp8)])
gmsh.model.occ.synchronize()
# Out:
# Info    : Recomputing incorrect OpenCASCADE wire in surface 397
# Info    : Recomputing incorrect OpenCASCADE wire in surface 398
# Info    : Recomputing incorrect OpenCASCADE wire in surface 400
# Info    : Recomputing incorrect OpenCASCADE wire in surface 401
# Info    : Recomputing incorrect OpenCASCADE wire in surface 407
# Info    : Recomputing incorrect OpenCASCADE wire in surface 408

# %%
gmsh.model.occ.synchronize()

for i in [28,24,32,8,16,12,23]:
    tag = gmsh.model.addPhysicalGroup(3, [i], tag=-1)
    gmsh.model.setPhysicalName(3, tag, ("overburden"+str(i)))
for i in [29,25,33,9,17,13,22]:
    tag = gmsh.model.addPhysicalGroup(3, [i], tag=-1)
    gmsh.model.setPhysicalName(3, tag, ("seal"+str(i)))
for i in [30,26,34,10,18,14,20]:
    tag = gmsh.model.addPhysicalGroup(3, [i], tag=-1)
    gmsh.model.setPhysicalName(3, tag, ("reservoir"+str(i)))
for i in [31,27,35,11,15,19,21]:
    tag = gmsh.model.addPhysicalGroup(3, [i], tag=-1)
    gmsh.model.setPhysicalName(3, tag, ("underburden"+str(i)))

# %%
# physical surface(model boundary/ fault) 
phy_s1 = gmsh.model.addPhysicalGroup(2, [394,386,220,351,279,210,243], tag=-1)
phy_s2 = gmsh.model.addPhysicalGroup(2, [315,407,216,333,405,397,403], tag=-1)
phy_s3 = gmsh.model.addPhysicalGroup(2, [396,404,406,359,263,377,234,363,370,381,241,209,277,385], tag=-1)
phy_s4 = gmsh.model.addPhysicalGroup(2, [318,335,217,399,402,390,344,218,361,247,392,349,219,365,238,395,353,221,211,245], tag=-1)
phy_s5 = gmsh.model.addPhysicalGroup(2, [408,319,378,389,382,391,387,393], tag=-1)
phy_s6 = gmsh.model.addPhysicalGroup(2, [401,398,246,360,235,364,242], tag=-1)
gmsh.model.setPhysicalName(2, phy_s1, "bot")
gmsh.model.setPhysicalName(2, phy_s2, "top")
gmsh.model.setPhysicalName(2, phy_s3, "-x")
gmsh.model.setPhysicalName(2, phy_s4, "+x")
gmsh.model.setPhysicalName(2, phy_s5, "-y")
gmsh.model.setPhysicalName(2, phy_s6, "+y")

# %%
# fault segment based on the intersection location.
for i in [259,264,265,271,272,278,141]: # top down, west east (fault plane) (x1)
    fault_grp = gmsh.model.addPhysicalGroup(2, [i], tag=-1)
    gmsh.model.setPhysicalName(2, fault_grp, ("flt1M-"+str(i)))

for i in [178,342,182,347,186,352,190]: # top down, west east (fault plane) (x1)
    fault_grp = gmsh.model.addPhysicalGroup(2, [i], tag=-1)
    gmsh.model.setPhysicalName(2, fault_grp, ("flt1A-"+str(i)))

for i in [334,340,268,269,345,276,281]: # top down, west east (fault plane) (x1) [6,169,142,141,173,146,147,111]
    fault_grp = gmsh.model.addPhysicalGroup(2, [i], tag=-1)
    gmsh.model.setPhysicalName(2, fault_grp, ("flt2M-"+str(i)))

for i in [400,362,366,212]: # top down, west east (fault plane) (x1) [6,169,142,141,173,146,147,111]
    fault_grp = gmsh.model.addPhysicalGroup(2, [i], tag=-1)
    gmsh.model.setPhysicalName(2, fault_grp, ("flt2A-"+str(i)))

# %%
# physical line(fault boundary)
phy_l1 = gmsh.model.addPhysicalGroup(1, [311,358,341,339,336,333,368,68,291,539,529,528,518,517,509,\
                                        643,562,573,572,651,527,526,654,595,537,543,319,394,395,668,666,699,698], tag=-1)
gmsh.model.setPhysicalName(1, phy_l1, "FB")

# intersection
phy_l1 = gmsh.model.addPhysicalGroup(1, [185,513,521,316,523,532,318,534,542,294], tag=-1)
gmsh.model.setPhysicalName(1, phy_l1, "FX")

# %%
# mesh size field (adaptive mesh size based on the distance from the fault and the reservoir boundaries.)
lc = 400
# mesh size near the fault
gmsh.model.mesh.field.add("Distance", 1)
gmsh.model.mesh.field.setNumbers(1, "FacesList", [264,265,271,272,278,342,182,347,186,352,340,268,269,345,276])
gmsh.model.mesh.field.setNumber(1, "Sampling", 2000)
gmsh.model.mesh.field.add("Threshold", 2)
gmsh.model.mesh.field.setNumber(2, "InField", 1)
gmsh.model.mesh.field.setNumber(2, "SizeMin", 2) # 6
gmsh.model.mesh.field.setNumber(2, "SizeMax", 100)
gmsh.model.mesh.field.setNumber(2, "DistMin", 4.0) # 12
gmsh.model.mesh.field.setNumber(2, "DistMax", 12.0)

# # reservoir interval
# gmsh.model.mesh.field.add("Box", 3)
# gmsh.model.mesh.field.setNumber(3, "VIn", 20)
# gmsh.model.mesh.field.setNumber(3, "VOut", 200)
# gmsh.model.mesh.field.setNumber(3, "XMin", 2.4e5)
# gmsh.model.mesh.field.setNumber(3, "XMax", 2.5e5)
# gmsh.model.mesh.field.setNumber(3, "YMin", 5.95e5)
# gmsh.model.mesh.field.setNumber(3, "YMax", 6.0e5)
# gmsh.model.mesh.field.setNumber(3, "ZMin", -3200)
# gmsh.model.mesh.field.setNumber(3, "ZMax", -2760)
# gmsh.model.mesh.field.setNumber(6, "Thickness", 0.3)

gmsh.model.mesh.field.add("Distance", 4)
gmsh.model.mesh.field.setNumbers(4, "FacesList", [294,301,323,329,273,266,185,181,214,215,201,206,239,236])
gmsh.model.mesh.field.setNumber(4, "Sampling", 2000)
gmsh.model.mesh.field.add("Threshold", 5)
gmsh.model.mesh.field.setNumber(5, "InField", 4)
gmsh.model.mesh.field.setNumber(5, "SizeMin", 30)
gmsh.model.mesh.field.setNumber(5, "SizeMax", 100)
gmsh.model.mesh.field.setNumber(5, "DistMin", 1.0)
gmsh.model.mesh.field.setNumber(5, "DistMax", 600.0)

gmsh.model.mesh.field.add("Min", 7)
gmsh.model.mesh.field.setNumbers(7, "FieldsList", [2,5])

gmsh.model.mesh.field.setAsBackgroundMesh(7)

gmsh.option.setNumber("Mesh.MeshSizeExtendFromBoundary", 0)
gmsh.option.setNumber("Mesh.MeshSizeFromPoints", 0)
gmsh.option.setNumber("Mesh.MeshSizeFromCurvature", 0)

# Finally, while the default "Frontal-Delaunay" 2D meshing algorithm
# (Mesh.Algorithm = 6) usually leads to the highest quality meshes, the
# "Delaunay" algorithm (Mesh.Algorithm = 5) will handle complex mesh size fields
# better - in particular size fields with large element size gradients:

gmsh.option.setNumber("Mesh.Algorithm", 6)

gmsh.model.mesh.generate(3)
gmsh.write("Zeerijp_anhydrite_xflt.msh")
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 68 (BSpline)
# Info    : [ 10%] Meshing curve 73 (BSpline)
# Info    : [ 10%] Meshing curve 80 (BSpline)
# Info    : [ 10%] Meshing curve 91 (BSpline)
# Info    : [ 10%] Meshing curve 97 (BSpline)
# Info    : [ 10%] Meshing curve 185 (BSpline)
# Info    : [ 10%] Meshing curve 194 (BSpline)
# Info    : [ 10%] Meshing curve 198 (BSpline)
# Info    : [ 10%] Meshing curve 200 (BSpline)
# Info    : [ 10%] Meshing curve 210 (BSpline)
# Info    : [ 10%] Meshing curve 212 (BSpline)
# Info    : [ 10%] Meshing curve 221 (BSpline)
# Info    : [ 10%] Meshing curve 224 (BSpline)
# Info    : [ 10%] Meshing curve 250 (BSpline)
# Info    : [ 10%] Meshing curve 261 (BSpline)
# Info    : [ 10%] Meshing curve 266 (BSpline)
# Info    : [ 10%] Meshing curve 271 (BSpline)
# Info    : [ 10%] Meshing curve 277 (BSpline)
# Info    : [ 10%] Meshing curve 279 (BSpline)
# Info    : [ 10%] Meshing curve 280 (BSpline)
# Info    : [ 10%] Meshing curve 289 (BSpline)
# Info    : [ 10%] Meshing curve 291 (BSpline)
# Info    : [ 10%] Meshing curve 292 (BSpline)
# Info    : [ 10%] Meshing curve 294 (BSpline)
# Info    : [ 10%] Meshing curve 299 (BSpline)
# Info    : [ 10%] Meshing curve 300 (BSpline)
# Info    : [ 20%] Meshing curve 302 (BSpline)
# Info    : [ 20%] Meshing curve 311 (BSpline)
# Info    : [ 20%] Meshing curve 312 (BSpline)
# Info    : [ 20%] Meshing curve 314 (BSpline)
# Info    : [ 20%] Meshing curve 316 (BSpline)
# Info    : [ 20%] Meshing curve 318 (BSpline)
# Info    : [ 20%] Meshing curve 319 (BSpline)
# Info    : [ 20%] Meshing curve 320 (BSpline)
# Info    : [ 20%] Meshing curve 321 (BSpline)
# Info    : [ 20%] Meshing curve 327 (BSpline)
# Info    : [ 20%] Meshing curve 329 (BSpline)
# Info    : [ 20%] Meshing curve 330 (BSpline)
# Info    : [ 20%] Meshing curve 331 (BSpline)
# Info    : [ 20%] Meshing curve 332 (BSpline)
# Info    : [ 20%] Meshing curve 333 (BSpline)
# Info    : [ 20%] Meshing curve 334 (BSpline)
# Info    : [ 20%] Meshing curve 335 (BSpline)
# Info    : [ 20%] Meshing curve 336 (BSpline)
# Info    : [ 20%] Meshing curve 337 (BSpline)
# Info    : [ 20%] Meshing curve 338 (BSpline)
# Info    : [ 20%] Meshing curve 339 (BSpline)
# Info    : [ 20%] Meshing curve 340 (BSpline)
# Info    : [ 20%] Meshing curve 341 (BSpline)
# Info    : [ 20%] Meshing curve 343 (BSpline)
# Info    : [ 20%] Meshing curve 344 (BSpline)
# Info    : [ 30%] Meshing curve 345 (BSpline)
# Info    : [ 30%] Meshing curve 346 (BSpline)
# Info    : [ 30%] Meshing curve 347 (BSpline)
# Info    : [ 30%] Meshing curve 348 (BSpline)
# Info    : [ 30%] Meshing curve 349 (BSpline)
# Info    : [ 30%] Meshing curve 350 (BSpline)
# Info    : [ 30%] Meshing curve 358 (BSpline)
# Info    : [ 30%] Meshing curve 360 (BSpline)
# Info    : [ 30%] Meshing curve 362 (BSpline)
# Info    : [ 30%] Meshing curve 363 (BSpline)
# Info    : [ 30%] Meshing curve 364 (BSpline)
# Info    : [ 30%] Meshing curve 365 (BSpline)
# Info    : [ 30%] Meshing curve 366 (BSpline)
# Info    : [ 30%] Meshing curve 367 (BSpline)
# Info    : [ 30%] Meshing curve 368 (BSpline)
# Info    : [ 30%] Meshing curve 370 (BSpline)
# Info    : [ 30%] Meshing curve 373 (BSpline)
# Info    : [ 30%] Meshing curve 377 (BSpline)
# Info    : [ 30%] Meshing curve 378 (BSpline)
# Info    : [ 30%] Meshing curve 379 (BSpline)
# Info    : [ 30%] Meshing curve 382 (BSpline)
# Info    : [ 30%] Meshing curve 383 (BSpline)
# Info    : [ 30%] Meshing curve 384 (BSpline)
# Info    : [ 30%] Meshing curve 385 (BSpline)
# Info    : [ 30%] Meshing curve 388 (BSpline)
# Info    : [ 40%] Meshing curve 389 (BSpline)
# Info    : [ 40%] Meshing curve 390 (BSpline)
# Info    : [ 40%] Meshing curve 392 (Line)
# Info    : [ 40%] Meshing curve 393 (Line)
# Info    : [ 40%] Meshing curve 394 (BSpline)
# Info    : [ 40%] Meshing curve 395 (BSpline)
# Info    : [ 40%] Meshing curve 396 (Line)
# Info    : [ 40%] Meshing curve 397 (Line)
# Info    : [ 40%] Meshing curve 398 (Line)
# Info    : [ 40%] Meshing curve 399 (Line)
# Info    : [ 40%] Meshing curve 400 (Line)
# Info    : [ 40%] Meshing curve 465 (Line)
# Info    : [ 40%] Meshing curve 466 (BSpline)
# Info    : [ 40%] Meshing curve 467 (BSpline)
# Info    : [ 40%] Meshing curve 468 (Line)
# Info    : [ 40%] Meshing curve 469 (BSpline)
# Info    : [ 40%] Meshing curve 470 (BSpline)
# Info    : [ 40%] Meshing curve 471 (BSpline)
# Info    : [ 40%] Meshing curve 472 (BSpline)
# Info    : [ 40%] Meshing curve 473 (BSpline)
# Info    : [ 40%] Meshing curve 474 (BSpline)
# Info    : [ 40%] Meshing curve 475 (BSpline)
# Info    : [ 40%] Meshing curve 476 (BSpline)
# Info    : [ 40%] Meshing curve 477 (BSpline)
# Info    : [ 40%] Meshing curve 478 (Line)
# Info    : [ 50%] Meshing curve 479 (Line)
# Info    : [ 50%] Meshing curve 480 (BSpline)
# Info    : [ 50%] Meshing curve 481 (Line)
# Info    : [ 50%] Meshing curve 482 (Line)
# Info    : [ 50%] Meshing curve 483 (Line)
# Info    : [ 50%] Meshing curve 484 (BSpline)
# Info    : [ 50%] Meshing curve 485 (Line)
# Info    : [ 50%] Meshing curve 486 (BSpline)
# Info    : [ 50%] Meshing curve 487 (BSpline)
# Info    : [ 50%] Meshing curve 488 (BSpline)
# Info    : [ 50%] Meshing curve 489 (BSpline)
# Info    : [ 50%] Meshing curve 490 (BSpline)
# Info    : [ 50%] Meshing curve 493 (BSpline)
# Info    : [ 50%] Meshing curve 495 (BSpline)
# Info    : [ 50%] Meshing curve 509 (BSpline)
# Info    : [ 50%] Meshing curve 510 (BSpline)
# Info    : [ 50%] Meshing curve 512 (BSpline)
# Info    : [ 50%] Meshing curve 513 (BSpline)
# Info    : [ 50%] Meshing curve 514 (BSpline)
# Info    : [ 50%] Meshing curve 515 (BSpline)
# Info    : [ 50%] Meshing curve 517 (BSpline)
# Info    : [ 50%] Meshing curve 518 (BSpline)
# Info    : [ 50%] Meshing curve 519 (BSpline)
# Info    : [ 50%] Meshing curve 520 (BSpline)
# Info    : [ 50%] Meshing curve 521 (BSpline)
# Info    : [ 60%] Meshing curve 522 (BSpline)
# Info    : [ 60%] Meshing curve 523 (BSpline)
# Info    : [ 60%] Meshing curve 524 (BSpline)
# Info    : [ 60%] Meshing curve 525 (BSpline)
# Info    : [ 60%] Meshing curve 526 (BSpline)
# Info    : [ 60%] Meshing curve 527 (BSpline)
# Info    : [ 60%] Meshing curve 528 (BSpline)
# Info    : [ 60%] Meshing curve 529 (BSpline)
# Info    : [ 60%] Meshing curve 530 (BSpline)
# Info    : [ 60%] Meshing curve 532 (BSpline)
# Info    : [ 60%] Meshing curve 533 (BSpline)
# Info    : [ 60%] Meshing curve 534 (BSpline)
# Info    : [ 60%] Meshing curve 535 (BSpline)
# Info    : [ 60%] Meshing curve 536 (BSpline)
# Info    : [ 60%] Meshing curve 537 (BSpline)
# Info    : [ 60%] Meshing curve 539 (BSpline)
# Info    : [ 60%] Meshing curve 540 (Line)
# Info    : [ 60%] Meshing curve 541 (BSpline)
# Info    : [ 60%] Meshing curve 542 (BSpline)
# Info    : [ 60%] Meshing curve 543 (BSpline)
# Info    : [ 60%] Meshing curve 557 (BSpline)
# Info    : [ 60%] Meshing curve 558 (BSpline)
# Info    : [ 60%] Meshing curve 561 (BSpline)
# Info    : [ 60%] Meshing curve 562 (BSpline)
# Info    : [ 60%] Meshing curve 563 (BSpline)
# Info    : [ 70%] Meshing curve 564 (BSpline)
# Info    : [ 70%] Meshing curve 565 (BSpline)
# Info    : [ 70%] Meshing curve 568 (BSpline)
# Info    : [ 70%] Meshing curve 569 (BSpline)
# Info    : [ 70%] Meshing curve 571 (BSpline)
# Info    : [ 70%] Meshing curve 572 (BSpline)
# Info    : [ 70%] Meshing curve 573 (BSpline)
# Info    : [ 70%] Meshing curve 574 (BSpline)
# Info    : [ 70%] Meshing curve 575 (BSpline)
# Info    : [ 70%] Meshing curve 576 (BSpline)
# Info    : [ 70%] Meshing curve 578 (BSpline)
# Info    : [ 70%] Meshing curve 581 (BSpline)
# Info    : [ 70%] Meshing curve 583 (BSpline)
# Info    : [ 70%] Meshing curve 586 (BSpline)
# Info    : [ 70%] Meshing curve 587 (BSpline)
# Info    : [ 70%] Meshing curve 588 (BSpline)
# Info    : [ 70%] Meshing curve 595 (BSpline)
# Info    : [ 70%] Meshing curve 598 (BSpline)
# Info    : [ 70%] Meshing curve 611 (Line)
# Info    : [ 70%] Meshing curve 612 (Line)
# Info    : [ 70%] Meshing curve 613 (BSpline)
# Info    : [ 70%] Meshing curve 614 (BSpline)
# Info    : [ 70%] Meshing curve 615 (BSpline)
# Info    : [ 70%] Meshing curve 616 (BSpline)
# Info    : [ 70%] Meshing curve 617 (BSpline)
# Info    : [ 80%] Meshing curve 618 (BSpline)
# Info    : [ 80%] Meshing curve 619 (Line)
# Info    : [ 80%] Meshing curve 620 (BSpline)
# Info    : [ 80%] Meshing curve 622 (BSpline)
# Info    : [ 80%] Meshing curve 624 (BSpline)
# Info    : [ 80%] Meshing curve 626 (BSpline)
# Info    : [ 80%] Meshing curve 627 (BSpline)
# Info    : [ 80%] Meshing curve 628 (BSpline)
# Info    : [ 80%] Meshing curve 629 (BSpline)
# Info    : [ 80%] Meshing curve 631 (BSpline)
# Info    : [ 80%] Meshing curve 633 (BSpline)
# Info    : [ 80%] Meshing curve 634 (BSpline)
# Info    : [ 80%] Meshing curve 635 (BSpline)
# Info    : [ 80%] Meshing curve 636 (BSpline)
# Info    : [ 80%] Meshing curve 638 (BSpline)
# Info    : [ 80%] Meshing curve 639 (BSpline)
# Info    : [ 80%] Meshing curve 640 (BSpline)
# Info    : [ 80%] Meshing curve 642 (BSpline)
# Info    : [ 80%] Meshing curve 643 (BSpline)
# Info    : [ 80%] Meshing curve 644 (Line)
# Info    : [ 80%] Meshing curve 645 (BSpline)
# Info    : [ 80%] Meshing curve 646 (BSpline)
# Info    : [ 80%] Meshing curve 647 (BSpline)
# Info    : [ 80%] Meshing curve 648 (BSpline)
# Info    : [ 80%] Meshing curve 649 (BSpline)
# Info    : [ 90%] Meshing curve 650 (BSpline)
# Info    : [ 90%] Meshing curve 651 (BSpline)
# Info    : [ 90%] Meshing curve 652 (BSpline)
# Info    : [ 90%] Meshing curve 653 (BSpline)
# Info    : [ 90%] Meshing curve 654 (BSpline)
# Info    : [ 90%] Meshing curve 655 (BSpline)
# Info    : [ 90%] Meshing curve 656 (BSpline)
# Info    : [ 90%] Meshing curve 657 (BSpline)
# Info    : [ 90%] Meshing curve 658 (Line)
# Info    : [ 90%] Meshing curve 665 (Line)
# Info    : [ 90%] Meshing curve 666 (BSpline)
# Info    : [ 90%] Meshing curve 667 (Line)
# Info    : [ 90%] Meshing curve 668 (BSpline)
# Info    : [ 90%] Meshing curve 670 (BSpline)
# Info    : [ 90%] Meshing curve 671 (BSpline)
# Info    : [ 90%] Meshing curve 672 (BSpline)
# Info    : [ 90%] Meshing curve 676 (BSpline)
# Info    : [ 90%] Meshing curve 677 (Line)
# Info    : [ 90%] Meshing curve 678 (BSpline)
# Info    : [ 90%] Meshing curve 679 (BSpline)
# Info    : [ 90%] Meshing curve 680 (Line)
# Info    : [ 90%] Meshing curve 681 (BSpline)
# Info    : [ 90%] Meshing curve 682 (BSpline)
# Info    : [ 90%] Meshing curve 683 (Line)
# Info    : [ 90%] Meshing curve 684 (Line)
# Info    : [100%] Meshing curve 685 (BSpline)
# Info    : [100%] Meshing curve 686 (Line)
# Info    : [100%] Meshing curve 687 (BSpline)
# Info    : [100%] Meshing curve 688 (Line)
# Info    : [100%] Meshing curve 689 (Line)
# Info    : [100%] Meshing curve 690 (Line)
# Info    : [100%] Meshing curve 691 (Line)
# Info    : [100%] Meshing curve 692 (Line)
# Info    : [100%] Meshing curve 693 (Line)
# Info    : [100%] Meshing curve 694 (Line)
# Info    : [100%] Meshing curve 695 (Line)
# Info    : [100%] Meshing curve 696 (Line)
# Info    : [100%] Meshing curve 697 (Line)
# Info    : [100%] Meshing curve 698 (BSpline)
# Info    : [100%] Meshing curve 699 (BSpline)
# Info    : [100%] Meshing curve 700 (Line)
# Info    : [100%] Meshing curve 701 (Line)
# Info    : [100%] Meshing curve 702 (Line)
# Info    : [100%] Meshing curve 703 (Line)
# Info    : [100%] Meshing curve 704 (Line)
# Info    : [100%] Meshing curve 705 (Line)
# Info    : [100%] Meshing curve 706 (Line)
# Info    : [100%] Meshing curve 707 (Line)
# Info    : [100%] Meshing curve 708 (Line)
# Info    : [100%] Meshing curve 709 (Line)
# Info    : Done meshing 1D (Wall 90.6152s, CPU 90.6316s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 104 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 127 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 139 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 141 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 162 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 163 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 164 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 165 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 167 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 168 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 169 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 170 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 178 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 181 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 182 (BSpline surface, Frontal-Delaunay)
# Info    : [ 10%] Meshing surface 185 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 186 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 190 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 196 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 201 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 206 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 209 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 210 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 211 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 212 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 213 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 214 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 215 (BSpline surface, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 216 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 217 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 218 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 219 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 220 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 221 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 234 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 235 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 236 (BSpline surface, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 237 (BSpline surface, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 238 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 239 (BSpline surface, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 240 (BSpline surface, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 241 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 242 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 243 (Plane, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 244 (BSpline surface, Frontal-Delaunay)
# Info    : [ 30%] Meshing surface 245 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 246 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 247 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 248 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 249 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 253 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 259 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 260 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 263 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 264 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 265 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 266 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 267 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 268 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 269 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 271 (BSpline surface, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 272 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 273 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 276 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 277 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 278 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 279 (Plane, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 280 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 281 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 287 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 288 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 293 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 294 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 298 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 301 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 311 (BSpline surface, Frontal-Delaunay)
# Info    : [ 50%] Meshing surface 315 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 316 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 317 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 318 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 319 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 320 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 323 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 326 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 329 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 330 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 332 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 333 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 334 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 335 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 336 (BSpline surface, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 337 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 338 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 339 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 340 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 341 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 342 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 343 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 344 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 345 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 346 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 347 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 348 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 349 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 350 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 351 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 352 (BSpline surface, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 353 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 359 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 360 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 361 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 362 (BSpline surface, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 363 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 364 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 365 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 366 (BSpline surface, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 369 (BSpline surface, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 370 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 371 (BSpline surface, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 372 (BSpline surface, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 376 (BSpline surface, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 377 (Plane, Frontal-Delaunay)
# Info    : [ 80%] Meshing surface 378 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 379 (BSpline surface, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 380 (BSpline surface, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 381 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 382 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 383 (BSpline surface, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 384 (BSpline surface, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 385 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 386 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 387 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 388 (BSpline surface, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 389 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 390 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 391 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 392 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 393 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 394 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 395 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 396 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 397 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 398 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 399 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 400 (BSpline surface, Frontal-Delaunay)
# Info    : [100%] Meshing surface 401 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 402 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 403 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 404 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 405 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 406 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 407 (Plane, Frontal-Delaunay)
# Info    : [100%] Meshing surface 408 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 36.087s, CPU 36.0557s)
# Info    : Meshing 3D...
# Info    : 3D Meshing 28 volumes with 1 connected component
# Info    : Tetrahedrizing 327800 nodes...
# Info    : Done tetrahedrizing 327808 nodes (Wall 8.01081s, CPU 7.76477s)
# Info    : Reconstructing mesh...
# Info    :  - Creating surface mesh
# Info    :  - Identifying boundary edges
# Info    :  - Recovering boundary
# Info    : Done reconstructing mesh (Wall 19.0231s, CPU 18.2471s)
# Info    : Found volume 10
# Info    : Found volume 26
# Info    : Found volume 14
# Info    : Found volume 25
# Info    : Found volume 30
# Info    : Found volume 9
# Info    : Found volume 11
# Info    : Found volume 24
# Info    : Found volume 27
# Info    : Found volume 12
# Info    : Found volume 31
# Info    : Found volume 13
# Info    : Found volume 8
# Info    : Found volume 28
# Info    : Found volume 21
# Info    : Found volume 20
# Info    : Found volume 18
# Info    : Found volume 34
# Info    : Found volume 23
# Info    : Found volume 35
# Info    : Found volume 32
# Info    : Found volume 16
# Info    : Found volume 19
# Info    : Found volume 15
# Info    : Found volume 29
# Info    : Found volume 22
# Info    : Found volume 33
# Info    : Found volume 17
# Info    : It. 0 - 0 nodes created - worst tet radius 68.9738 (nodes removed 0 0)
# Info    : It. 500 - 488 nodes created - worst tet radius 5.50302 (nodes removed 0 12)
# Info    : It. 1000 - 987 nodes created - worst tet radius 4.34076 (nodes removed 0 13)
# Info    : It. 1500 - 1483 nodes created - worst tet radius 3.79989 (nodes removed 0 17)
# Info    : It. 2000 - 1979 nodes created - worst tet radius 3.48261 (nodes removed 0 21)
# Info    : It. 2500 - 2478 nodes created - worst tet radius 3.25176 (nodes removed 0 22)
# Info    : It. 3000 - 2974 nodes created - worst tet radius 3.06384 (nodes removed 1 25)
)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :        12 elements
# Info    : 0.10 < quality < 0.20 :       107 elements
# Info    : 0.20 < quality < 0.30 :       924 elements
# Info    : 0.30 < quality < 0.40 :     10343 elements
# Info    : 0.40 < quality < 0.50 :     14498 elements
# Info    : 0.50 < quality < 0.60 :     20554 elements
# Info    : 0.60 < quality < 0.70 :     35189 elements
# Info    : 0.70 < quality < 0.80 :     62977 elements
# Info    : 0.80 < quality < 0.90 :     69835 elements
# Info    : 0.90 < quality < 1.00 :     30966 elements
# Info    : Optimizing volume 26
# Info    : Optimization starts (volume = 1.57254e+08) with worst = 2.82209e-05 / average = 0.727832:
# Info    : 0.00 < quality < 0.10 :      4887 elements
# Info    : 0.10 < quality < 0.20 :     14769 elements
# Info    : 0.20 < quality < 0.30 :     33894 elements
# Info    : 0.30 < quality < 0.40 :     53756 elements
# Info    : 0.40 < quality < 0.50 :     74898 elements
# Info    : 0.50 < quality < 0.60 :    102813 elements
# Info    : 0.60 < quality < 0.70 :    177327 elements
# Info    : 0.70 < quality < 0.80 :    346174 elements
# Info    : 0.80 < quality < 0.90 :    418502 elements
# Info    : 0.90 < quality < 1.00 :    189487 elements
# Info    : 41820 edge swaps, 7330 node relocations (volume = 1.57254e+08): worst = 0.0272875 / average = 0.742106 (Wall 3.14307s, CPU 3.14295s)
# Info    : 44839 edge swaps, 9171 node relocations (volume = 1.57254e+08): worst = 0.0346973 / average = 0.742519 (Wall 4.68622s, CPU 4.68682s)
# Info    : 45410 edge swaps, 9893 node relocations (volume = 1.57254e+08): worst = 0.0346973 / average = 0.742572 (Wall 6.15662s, CPU 6.15808s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :        36 elements
# Info    : 0.10 < quality < 0.20 :       344 elements
# Info    : 0.20 < quality < 0.30 :      5062 elements
# Info    : 0.30 < quality < 0.40 :     57943 elements
# Info    : 0.40 < quality < 0.50 :     79019 elements
# Info    : 0.50 < quality < 0.60 :    106811 elements
# Info    : 0.60 < quality < 0.70 :    181362 elements
# Info    : 0.70 < quality < 0.80 :    346091 elements
# Info    : 0.80 < quality < 0.90 :    420037 elements
# Info    : 0.90 < quality < 1.00 :    186407 elements
# Info    : Optimizing volume 27
# Info    : Optimization starts (volume = 1.05824e+08) with worst = 0.00067319 / average = 0.701652:
# Info    : 0.00 < quality < 0.10 :       341 elements
# Info    : 0.10 < quality < 0.20 :      1083 elements
# Info    : 0.20 < quality < 0.30 :      2533 elements
# Info    : 0.30 < quality < 0.40 :      4162 elements
# Info    : 0.40 < quality < 0.50 :      5339 elements
# Info    : 0.50 < quality < 0.60 :      7004 elements
# Info    : 0.60 < quality < 0.70 :     10964 elements
# Info    : 0.70 < quality < 0.80 :     18997 elements
# Info    : 0.80 < quality < 0.90 :     21460 elements
# Info    : 0.90 < quality < 1.00 :      9251 elements
# Info    : 2595 edge swaps, 404 node relocations (volume = 1.05824e+08): worst = 0.00732933 / average = 0.71571 (Wall 0.200817s, CPU 0.201269s)
# Info    : 2844 edge swaps, 521 node relocations (volume = 1.05824e+08): worst = 0.00732933 / average = 0.71623 (Wall 0.303885s, CPU 0.30526s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         1 elements
# Info    : 0.10 < quality < 0.20 :       134 elements
# Info    : 0.20 < quality < 0.30 :       939 elements
# Info    : 0.30 < quality < 0.40 :      4277 elements
# Info    : 0.40 < quality < 0.50 :      5534 elements
# Info    : 0.50 < quality < 0.60 :      7159 elements
# Info    : 0.60 < quality < 0.70 :     11030 elements
# Info    : 0.70 < quality < 0.80 :     18976 elements
# Info    : 0.80 < quality < 0.90 :     21525 elements
# Info    : 0.90 < quality < 1.00 :      9096 elements
# Info    : Optimizing volume 28
# Info    : Optimization starts (volume = 3.44243e+08) with worst = 0.0104323 / average = 0.762517:
# Info    : 0.00 < quality < 0.10 :        41 elements
# Info    : 0.10 < quality < 0.20 :        96 elements
# Info    : 0.20 < quality < 0.30 :       126 elements
# Info    : 0.30 < quality < 0.40 :       192 elements
# Info    : 0.40 < quality < 0.50 :       361 elements
# Info    : 0.50 < quality < 0.60 :       664 elements
# Info    : 0.60 < quality < 0.70 :      1513 elements
# Info    : 0.70 < quality < 0.80 :      3390 elements
# Info    : 0.80 < quality < 0.90 :      4037 elements
# Info    : 0.90 < quality < 1.00 :      1843 elements
# Info    : 260 edge swaps, 10 node relocations (volume = 3.44243e+08): worst = 0.271521 / average = 0.775232 (Wall 0.020134s, CPU 0.020673s)
# Info    : 264 edge swaps, 10 node relocations (volume = 3.44243e+08): worst = 0.300128 / average = 0.775388 (Wall 0.0256082s, CPU 0.026566s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :       201 elements
# Info    : 0.40 < quality < 0.50 :       338 elements
# Info    : 0.50 < quality < 0.60 :       665 elements
# Info    : 0.60 < quality < 0.70 :      1496 elements
# Info    : 0.70 < quality < 0.80 :      3439 elements
# Info    : 0.80 < quality < 0.90 :      4072 elements
# Info    : 0.90 < quality < 1.00 :      1823 elements
# Info    : Optimizing volume 29
# Info    : Optimization starts (volume = 4.22339e+07) with worst = 0.0122503 / average = 0.70934:
# Info    : 0.00 < quality < 0.10 :        79 elements
# Info    : 0.10 < quality < 0.20 :        42 elements
# Info    : 0.20 < quality < 0.30 :        57 elements
# Info    : 0.30 < quality < 0.40 :        77 elements
# Info    : 0.40 < quality < 0.50 :       105 elements
# Info    : 0.50 < quality < 0.60 :       255 elements
# Info    : 0.60 < quality < 0.70 :      1833 elements
# Info    : 0.70 < quality < 0.80 :      2686 elements
# Info    : 0.80 < quality < 0.90 :      1256 elements
# Info    : 0.90 < quality < 1.00 :       208 elements
# Info    : 132 edge swaps, 0 node relocations (volume = 4.22339e+07): worst = 0.0913805 / average = 0.722 (Wall 0.0124609s, CPU 0.012938s)
# Info    : 135 edge swaps, 0 node relocations (volume = 4.22339e+07): worst = 0.166569 / average = 0.72218 (Wall 0.016435s, CPU 0.0134s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         9 elements
# Info    : 0.20 < quality < 0.30 :        38 elements
# Info    : 0.30 < quality < 0.40 :        77 elements
# Info    : 0.40 < quality < 0.50 :        95 elements
# Info    : 0.50 < quality < 0.60 :       239 elements
# Info    : 0.60 < quality < 0.70 :      1871 elements
# Info    : 0.70 < quality < 0.80 :      2702 elements
# Info    : 0.80 < quality < 0.90 :      1236 elements
# Info    : 0.90 < quality < 1.00 :       207 elements
# Info    : Optimizing volume 30
# Info    : Optimization starts (volume = 2.34524e+08) with worst = 0.00775513 / average = 0.727332:
# Info    : 0.00 < quality < 0.10 :       115 elements
# Info    : 0.10 < quality < 0.20 :       791 elements
# Info    : 0.20 < quality < 0.30 :       978 elements
# Info    : 0.30 < quality < 0.40 :       698 elements
# Info    : 0.40 < quality < 0.50 :       924 elements
# Info    : 0.50 < quality < 0.60 :      1595 elements
# Info    : 0.60 < quality < 0.70 :      3260 elements
# Info    : 0.70 < quality < 0.80 :      7381 elements
# Info    : 0.80 < quality < 0.90 :      8618 elements
# Info    : 0.90 < quality < 1.00 :      3757 elements
# Info    : 604 edge swaps, 18 node relocations (volume = 2.34524e+08): worst = 0.0550555 / average = 0.739198 (Wall 0.290233s, CPU 0.291321s)
# Info    : 633 edge swaps, 31 node relocations (volume = 2.34524e+08): worst = 0.0550555 / average = 0.739331 (Wall 0.377246s, CPU 0.378679s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         8 elements
# Info    : 0.10 < quality < 0.20 :       555 elements
# Info    : 0.20 < quality < 0.30 :       707 elements
# Info    : 0.30 < quality < 0.40 :       693 elements
# Info    : 0.40 < quality < 0.50 :       899 elements
# Info    : 0.50 < quality < 0.60 :      1596 elements
# Info    : 0.60 < quality < 0.70 :      3232 elements
# Info    : 0.70 < quality < 0.80 :      7425 elements
# Info    : 0.80 < quality < 0.90 :      8710 elements
# Info    : 0.90 < quality < 1.00 :      3733 elements
# Info    : Optimizing volume 31
# Info    : Optimization starts (volume = 2.352e+08) with worst = 0.00797932 / average = 0.750432:
# Info    : 0.00 < quality < 0.10 :        73 elements
# Info    : 0.10 < quality < 0.20 :       236 elements
# Info    : 0.20 < quality < 0.30 :       396 elements
# Info    : 0.30 < quality < 0.40 :       382 elements
# Info    : 0.40 < quality < 0.50 :       606 elements
# Info    : 0.50 < quality < 0.60 :      1060 elements
# Info    : 0.60 < quality < 0.70 :      2294 elements
# Info    : 0.70 < quality < 0.80 :      4947 elements
# Info    : 0.80 < quality < 0.90 :      6248 elements
# Info    : 0.90 < quality < 1.00 :      2761 elements
# Info    : 415 edge swaps, 9 node relocations (volume = 2.352e+08): worst = 0.0627437 / average = 0.763151 (Wall 0.0388814s, CPU 0.039248s)
# Info    : 426 edge swaps, 12 node relocations (volume = 2.352e+08): worst = 0.0627437 / average = 0.763225 (Wall 0.0590057s, CPU 0.059701s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         3 elements
# Info    : 0.10 < quality < 0.20 :        77 elements
# Info    : 0.20 < quality < 0.30 :       197 elements
# Info    : 0.30 < quality < 0.40 :       384 elements
# Info    : 0.40 < quality < 0.50 :       585 elements
# Info    : 0.50 < quality < 0.60 :      1076 elements
# Info    : 0.60 < quality < 0.70 :      2272 elements
# Info    : 0.70 < quality < 0.80 :      4964 elements
# Info    : 0.80 < quality < 0.90 :      6318 elements
# Info    : 0.90 < quality < 1.00 :      2747 elements
# Info    : Optimizing volume 32
# Info    : Optimization starts (volume = 6.95119e+07) with worst = 0.0184542 / average = 0.754499:
# Info    : 0.00 < quality < 0.10 :         9 elements
# Info    : 0.10 < quality < 0.20 :        14 elements
# Info    : 0.20 < quality < 0.30 :        35 elements
# Info    : 0.30 < quality < 0.40 :        50 elements
# Info    : 0.40 < quality < 0.50 :        77 elements
# Info    : 0.50 < quality < 0.60 :       157 elements
# Info    : 0.60 < quality < 0.70 :       430 elements
# Info    : 0.70 < quality < 0.80 :       787 elements
# Info    : 0.80 < quality < 0.90 :       834 elements
# Info    : 0.90 < quality < 1.00 :       383 elements
# Info    : 57 edge swaps, 0 node relocations (volume = 6.95119e+07): worst = 0.300976 / average = 0.767297 (Wall 0.00231143s, CPU 0s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         0 elements
# Info    : 0.30 < quality < 0.40 :        48 elements
# Info    : 0.40 < quality < 0.50 :        72 elements
# Info    : 0.50 < quality < 0.60 :       165 elements
# Info    : 0.60 < quality < 0.70 :       415 elements
# Info    : 0.70 < quality < 0.80 :       793 elements
# Info    : 0.80 < quality < 0.90 :       847 elements
# Info    : 0.90 < quality < 1.00 :       383 elements
# Info    : Optimizing volume 33
# Info    : Optimization starts (volume = 9.5727e+06) with worst = 0.0503324 / average = 0.701351:
# Info    : 0.00 < quality < 0.10 :        10 elements
# Info    : 0.10 < quality < 0.20 :        13 elements
# Info    : 0.20 < quality < 0.30 :        25 elements
# Info    : 0.30 < quality < 0.40 :        93 elements
# Info    : 0.40 < quality < 0.50 :        67 elements
# Info    : 0.50 < quality < 0.60 :        66 elements
# Info    : 0.60 < quality < 0.70 :       259 elements
# Info    : 0.70 < quality < 0.80 :       771 elements
# Info    : 0.80 < quality < 0.90 :       262 elements
# Info    : 0.90 < quality < 1.00 :        90 elements
# Info    : 32 edge swaps, 0 node relocations (volume = 9.5727e+06): worst = 0.0901965 / average = 0.711685 (Wall 0.00349522s, CPU 0.004393s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         3 elements
# Info    : 0.10 < quality < 0.20 :         4 elements
# Info    : 0.20 < quality < 0.30 :         9 elements
# Info    : 0.30 < quality < 0.40 :        95 elements
# Info    : 0.40 < quality < 0.50 :        67 elements
# Info    : 0.50 < quality < 0.60 :        56 elements
# Info    : 0.60 < quality < 0.70 :       270 elements
# Info    : 0.70 < quality < 0.80 :       772 elements
# Info    : 0.80 < quality < 0.90 :       263 elements
# Info    : 0.90 < quality < 1.00 :        90 elements
# Info    : Optimizing volume 34
# Info    : Optimization starts (volume = 5.50707e+07) with worst = 0.00744784 / average = 0.750809:
# Info    : 0.00 < quality < 0.10 :        23 elements
# Info    : 0.10 < quality < 0.20 :        50 elements
# Info    : 0.20 < quality < 0.30 :        77 elements
# Info    : 0.30 < quality < 0.40 :       139 elements
# Info    : 0.40 < quality < 0.50 :       215 elements
# Info    : 0.50 < quality < 0.60 :       394 elements
# Info    : 0.60 < quality < 0.70 :       899 elements
# Info    : 0.70 < quality < 0.80 :      1864 elements
# Info    : 0.80 < quality < 0.90 :      2081 elements
# Info    : 0.90 < quality < 1.00 :       882 elements
# Info    : 130 edge swaps, 1 node relocations (volume = 5.50707e+07): worst = 0.074659 / average = 0.762538 (Wall 0.0111897s, CPU 0.011945s)
# Info    : 133 edge swaps, 1 node relocations (volume = 5.50707e+07): worst = 0.074659 / average = 0.762834 (Wall 0.0130155s, CPU 0.014104s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         3 elements
# Info    : 0.10 < quality < 0.20 :         6 elements
# Info    : 0.20 < quality < 0.30 :         7 elements
# Info    : 0.30 < quality < 0.40 :       136 elements
# Info    : 0.40 < quality < 0.50 :       217 elements
# Info    : 0.50 < quality < 0.60 :       405 elements
# Info    : 0.60 < quality < 0.70 :       876 elements
# Info    : 0.70 < quality < 0.80 :      1868 elements
# Info    : 0.80 < quality < 0.90 :      2101 elements
# Info    : 0.90 < quality < 1.00 :       886 elements
# Info    : Optimizing volume 35
# Info    : Optimization starts (volume = 5.91293e+07) with worst = 0.0235984 / average = 0.756615:
# Info    : 0.00 < quality < 0.10 :        17 elements
# Info    : 0.10 < quality < 0.20 :        35 elements
# Info    : 0.20 < quality < 0.30 :        59 elements
# Info    : 0.30 < quality < 0.40 :        75 elements
# Info    : 0.40 < quality < 0.50 :       163 elements
# Info    : 0.50 < quality < 0.60 :       295 elements
# Info    : 0.60 < quality < 0.70 :       705 elements
# Info    : 0.70 < quality < 0.80 :      1275 elements
# Info    : 0.80 < quality < 0.90 :      1574 elements
# Info    : 0.90 < quality < 1.00 :       731 elements
# Info    : 109 edge swaps, 2 node relocations (volume = 5.91293e+07): worst = 0.248677 / average = 0.770224 (Wall 0.00728492s, CPU 0.007784s)
# Info    : 111 edge swaps, 2 node relocations (volume = 5.91293e+07): worst = 0.283651 / average = 0.770335 (Wall 0.0113139s, CPU 0.012211s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         0 elements
# Info    : 0.20 < quality < 0.30 :         1 elements
# Info    : 0.30 < quality < 0.40 :        71 elements
# Info    : 0.40 < quality < 0.50 :       157 elements
# Info    : 0.50 < quality < 0.60 :       304 elements
# Info    : 0.60 < quality < 0.70 :       696 elements
# Info    : 0.70 < quality < 0.80 :      1278 elements
# Info    : 0.80 < quality < 0.90 :      1594 elements
# Info    : 0.90 < quality < 1.00 :       729 elements
# Info    : Done optimizing mesh (Wall 56.9279s, CPU 56.4825s)
# Info    : 957490 nodes 6469670 elements
# Info    : Writing 'Zeerijp_anhydrite_xflt.msh'...
# Info    : Done writing 'Zeerijp_anhydrite_xflt.msh'

# %%
gmsh.model.occ.synchronize()

if '-nopopup' not in sys.argv:
    gmsh.fltk.run()
gmsh.finalize()
# Out:
# -------------------------------------------------------
# Version       : 4.9.0
# License       : GNU General Public License
# Build OS      : Linux64-sdk
# Build date    : 20211203
# Build host    : gmsh.info
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blas[petsc] Blossom Cgns DIntegration Dlopen DomHex Eigen[contrib] Fltk Gmm[contrib] Hxt Jpeg Kbipack Lapack[petsc] LinuxJoystick MathEx[contrib] Med Mesh Metis[contrib] Mmg Mpeg Netgen ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom PETSc Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR Voro++[contrib] WinslowUntangler Zlib
# FLTK version  : 1.4.0
# PETSc version : 3.14.4 (real arithmtic)
# OCC version   : 7.6.0
# MED version   : 4.1.0
# Packaged by   : geuzaine
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------
