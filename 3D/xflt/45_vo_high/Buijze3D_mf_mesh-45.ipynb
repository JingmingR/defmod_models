# %%
# ------------------------------------------------------------------------------
#
#  GMSH-CAD Groningen model desgin 
#
#  STEP import and manipulation, geometry partitioning
#  02-03-2022: a flat fault example for comparison;
# ------------------------------------------------------------------------------

# %%
import gmsh
import math
import os
import sys
import numpy as np

# %%
help(gmsh.model.occ.fuse)
# Out:
# Help on function fuse in module gmsh:
#
# fuse(objectDimTags, toolDimTags, tag=-1, removeObject=True, removeTool=True)
#     gmsh.model.occ.fuse(objectDimTags, toolDimTags, tag=-1, removeObject=True, removeTool=True)
#
#     Compute the boolean union (the fusion) of the entities `objectDimTags' and
#     `toolDimTags' in the OpenCASCADE CAD representation. Return the resulting
#     entities in `outDimTags'. If `tag' is positive, try to set the tag
#     explicitly (only valid if the boolean operation results in a single
#     entity). Remove the object if `removeObject' is set. Remove the tool if
#     `removeTool' is set.
#
#     Return `outDimTags', `outDimTagsMap'.

# %%
gmsh.initialize()
gmsh.model.add("Simple_cube")

# %%
lc = 400
tp1 = gmsh.model.occ.addPoint(0, 0, -1200)
tp2 = gmsh.model.occ.addPoint(0, 4000, -1200)
tp3 = gmsh.model.occ.addPoint(4000, 4000, -1200)
tp4 = gmsh.model.occ.addPoint(4000, 0, -1200)


tl1 = gmsh.model.occ.addLine(tp1, tp2)
tl2 = gmsh.model.occ.addLine(tp2, tp3)
tl3 = gmsh.model.occ.addLine(tp3, tp4)
tl4 = gmsh.model.occ.addLine(tp4, tp1)


tll1 = gmsh.model.occ.addCurveLoop([tl1, tl2, tl3, tl4])
ts1 = gmsh.model.occ.addPlaneSurface([tll1])
gmsh.model.occ.synchronize()

ov = gmsh.model.occ.extrude([(2,ts1)], 0, 0, -1600)
ov = gmsh.model.occ.extrude([ov[0]], 0, 0, -50)
ov = gmsh.model.occ.extrude([ov[0]], 0, 0, -50)
ov = gmsh.model.occ.extrude([ov[0]], 0, 0, -100)
ov = gmsh.model.occ.extrude([ov[0]], 0, 0, -50)
ov = gmsh.model.occ.extrude([ov[0]], 0, 0, -50)
ov = gmsh.model.occ.extrude([ov[0]], 0, 0, -1900)


fp1 = gmsh.model.occ.addPoint(2000+1900*math.tan(math.pi*24/180), 0, -5000, lc);
fp2 = gmsh.model.occ.addPoint(2000-1900*math.tan(math.pi*24/180), 0, -1200, lc);
fp3 = gmsh.model.occ.addPoint(2000-1900*math.tan(math.pi*24/180), 4000, -1200, lc);
fp4 = gmsh.model.occ.addPoint(2000+1900*math.tan(math.pi*24/180), 4000, -5000, lc);
fl1 = gmsh.model.occ.addLine(fp1, fp2)
fl2 = gmsh.model.occ.addLine(fp2, fp3)
fl3 = gmsh.model.occ.addLine(fp3, fp4)
fl4 = gmsh.model.occ.addLine(fp4, fp1)
fcl1 = gmsh.model.occ.addCurveLoop([fl1, fl2, fl3, fl4])
fs1 = gmsh.model.occ.addPlaneSurface([fcl1])

fp1 = gmsh.model.occ.addPoint(0,2000+1900*math.tan(math.pi*0/180)-2000*math.tan(math.pi*45/180),  -5000, lc);
fp2 = gmsh.model.occ.addPoint(0,2000-1900*math.tan(math.pi*0/180)-2000*math.tan(math.pi*45/180),  -1200, lc);
fp3 = gmsh.model.occ.addPoint(4000,2000-1900*math.tan(math.pi*0/180)+2000*math.tan(math.pi*45/180),  -1200, lc);
fp4 = gmsh.model.occ.addPoint(4000,2000+1900*math.tan(math.pi*0/180)+2000*math.tan(math.pi*45/180),  -5000, lc);
fl1 = gmsh.model.occ.addLine(fp1, fp2)
fl2 = gmsh.model.occ.addLine(fp2, fp3)
fl3 = gmsh.model.occ.addLine(fp3, fp4)
fl4 = gmsh.model.occ.addLine(fp4, fp1)
fcl1 = gmsh.model.occ.addCurveLoop([fl1, fl2, fl3, fl4])
fs2 = gmsh.model.occ.addPlaneSurface([fcl1])

# %%
gmsh.model.occ.fragment(gmsh.model.occ.getEntities(3),[(2,fs1),(2,fs2)])
gmsh.model.occ.synchronize()

# gmsh.model.occ.fragment(gmsh.model.occ.getEntities(3),[(2,fs1)])
# gmsh.model.occ.fragment([(3,1),(3,3),(3,5),(3,7),(3,9),(3,11),(3,13)],[(2,fs2)])
# gmsh.model.occ.synchronize()
# Out:
# Info    : Recomputing incorrect OpenCASCADE wire in surface 1
# Info    : Recomputing incorrect OpenCASCADE wire in surface 14
# Info    : Recomputing incorrect OpenCASCADE wire in surface 19
# Info    : Recomputing incorrect OpenCASCADE wire in surface 29
# Info    : Recomputing incorrect OpenCASCADE wire in surface 33
# Info    : Recomputing incorrect OpenCASCADE wire in surface 43
# Info    : Recomputing incorrect OpenCASCADE wire in surface 47
# Info    : Recomputing incorrect OpenCASCADE wire in surface 57
# Info    : Recomputing incorrect OpenCASCADE wire in surface 61
# Info    : Recomputing incorrect OpenCASCADE wire in surface 71
# Info    : Recomputing incorrect OpenCASCADE wire in surface 75
# Info    : Recomputing incorrect OpenCASCADE wire in surface 85
# Info    : Recomputing incorrect OpenCASCADE wire in surface 89
# Info    : Recomputing incorrect OpenCASCADE wire in surface 99

# %%
fu1 = gmsh.model.occ.fuse([(3,6)],[(3,10)])
fu2 = gmsh.model.occ.fuse([(3,18)],[(3,22)])

# %%
fl1 = gmsh.model.occ.addLine(26, 5)
fl2 = gmsh.model.occ.addLine(2, 26)

W1 = gmsh.model.occ.addCurveLoop([fl1, -5, fl2])
BS1 = gmsh.model.occ.addPlaneSurface([W1])

fl1 = gmsh.model.occ.addLine(47, 31)
fl2 = gmsh.model.occ.addLine(29, 47)

W1 = gmsh.model.occ.addCurveLoop([fl1, -65, fl2])
BS2 = gmsh.model.occ.addPlaneSurface([W1])
gmsh.model.occ.fragment(fu1[0],[(2,BS1)])
gmsh.model.occ.fragment(fu2[0],[(2,BS2)])
# Out:
# ([(2, 110), (3, 33), (3, 34)], [[(3, 33), (3, 34)], [(2, 110)]])

# %%
# step 1 high
gmsh.model.occ.fuse([(3,2)],[(3,31)])
gmsh.model.occ.fuse([(3,14)],[(3,32),(3,33)])
gmsh.model.occ.fuse([(3,26)],[(3,34)])
# step 2 mid
gmsh.model.occ.fuse([(3,1)],[(3,5)])
gmsh.model.occ.fuse([(3,9)],[(3,13),(3,17)])
gmsh.model.occ.fuse([(3,21)],[(3,25)])
# step 3 low 1
gmsh.model.occ.fuse([(3,3)],[(3,7),(3,11)])
gmsh.model.occ.fuse([(3,15)],[(3,19),(3,23)])
# step 3 low 2
gmsh.model.occ.fuse([(3,4)],[(3,8),(3,12)])
gmsh.model.occ.fuse([(3,16)],[(3,20),(3,24)])
gmsh.model.occ.removeAllDuplicates()

# %%
tp5 = gmsh.model.occ.addPoint(0, 2000, -1200)
tp6 = gmsh.model.occ.addPoint(2000, 4000, -1200)
tp7 = gmsh.model.occ.addPoint(4000, 2000, -1200)
tp8 = gmsh.model.occ.addPoint(2000, 0, -1200)

gmsh.model.occ.fragment(gmsh.model.occ.getEntities(3),[(0,tp5),(0,tp6),(0,tp7),(0,tp8)])
gmsh.model.occ.synchronize()
# Out:
# Info    : Recomputing incorrect OpenCASCADE wire in surface 124
# Info    : Recomputing incorrect OpenCASCADE wire in surface 129
# Info    : Recomputing incorrect OpenCASCADE wire in surface 138
# Info    : Recomputing incorrect OpenCASCADE wire in surface 139
# Info    : Recomputing incorrect OpenCASCADE wire in surface 143
# Info    : Recomputing incorrect OpenCASCADE wire in surface 149
# Info    : Recomputing incorrect OpenCASCADE wire in surface 152
# Info    : Recomputing incorrect OpenCASCADE wire in surface 156
# Info    : Recomputing incorrect OpenCASCADE wire in surface 158
# Info    : Recomputing incorrect OpenCASCADE wire in surface 159
# Info    : Recomputing incorrect OpenCASCADE wire in surface 160
# Info    : Recomputing incorrect OpenCASCADE wire in surface 161
# Info    : Recomputing incorrect OpenCASCADE wire in surface 162
# Info    : Recomputing incorrect OpenCASCADE wire in surface 163

# %%
gmsh.model.occ.synchronize()


for i in [35,38,41,43]:
    tag = gmsh.model.addPhysicalGroup(3, [i], tag=-1)
    gmsh.model.setPhysicalName(3, tag, ("overburden"+str(i)))
for i in [36,39,42,44]:
    tag = gmsh.model.addPhysicalGroup(3, [i], tag=-1)
    gmsh.model.setPhysicalName(3, tag, ("reservoir"+str(i)))
for i in [37,40,27,28]:
    tag = gmsh.model.addPhysicalGroup(3, [i], tag=-1)
    gmsh.model.setPhysicalName(3, tag, ("underburden"+str(i)))

    
# physical surface(model boundary/ fault)
phy_s1 = gmsh.model.addPhysicalGroup(2, [132,145,98,101], tag=-1)
phy_s2 = gmsh.model.addPhysicalGroup(2, [122,158,163,160], tag=-1)
phy_s3 = gmsh.model.addPhysicalGroup(2, [156,138,142], tag=-1) # 124,103,107,116,111,113
phy_s4 = gmsh.model.addPhysicalGroup(2, [161,151,99], tag=-1)
phy_s5 = gmsh.model.addPhysicalGroup(2, [159,121,150,124,97,129], tag=-1)
phy_s6 = gmsh.model.addPhysicalGroup(2, [162,157,155,139,102,143], tag=-1)
    
gmsh.model.setPhysicalName(2, phy_s1, "bot")
gmsh.model.setPhysicalName(2, phy_s2, "top")
gmsh.model.setPhysicalName(2, phy_s3, "-x")
gmsh.model.setPhysicalName(2, phy_s4, "+x")
gmsh.model.setPhysicalName(2, phy_s5, "-y")
gmsh.model.setPhysicalName(2, phy_s6, "+y")

    
# fault segment based on the intersection location.
for i in [123,128,127,133,96]: # top down, west east (fault plane) (x1)
    fault_grp = gmsh.model.addPhysicalGroup(2, [i], tag=-1)
    gmsh.model.setPhysicalName(2, fault_grp, ("flt1M-"+str(i)))

for i in [137,140,141,144,93]: # top down, west east (fault plane) (x1)
    fault_grp = gmsh.model.addPhysicalGroup(2, [i], tag=-1)
    gmsh.model.setPhysicalName(2, fault_grp, ("flt1A-"+str(i)))

for i in [2,126,125,130,131]: # top down, west east (fault plane) (x1) [6,169,142,141,173,146,147,111]
    fault_grp = gmsh.model.addPhysicalGroup(2, [i], tag=-1)
    gmsh.model.setPhysicalName(2, fault_grp, ("flt2M-"+str(i)))

for i in [149,152,100]: # top down, west east (fault plane) (x1) [6,169,142,141,173,146,147,111]
    fault_grp = gmsh.model.addPhysicalGroup(2, [i], tag=-1)
    gmsh.model.setPhysicalName(2, fault_grp, ("flt2A-"+str(i)))
    
# physical line(fault boundary)
phy_l1 = gmsh.model.addPhysicalGroup(1, [16,164,163,166,167,171,118,120,123,122,150,147,\
                                        7,175,176,178,128,127,158,155,154,149,148,1], tag=-1)
gmsh.model.setPhysicalName(1, phy_l1, "FB")

# intersection
phy_l1 = gmsh.model.addPhysicalGroup(1, [6,153,152,151,157,159,117], tag=-1)
gmsh.model.setPhysicalName(1, phy_l1, "FX")

# %%
# mesh size field
# mesh size near the fault
gmsh.model.mesh.field.add("Distance", 1)
gmsh.model.mesh.field.setNumbers(1, "FacesList", [128,127,133,140,141,144,\
                                                  126,125,130])
gmsh.model.mesh.field.setNumber(1, "Sampling", 1000)
gmsh.model.mesh.field.add("Threshold", 2)
gmsh.model.mesh.field.setNumber(2, "InField", 1)
gmsh.model.mesh.field.setNumber(2, "SizeMin", 4) # 40
gmsh.model.mesh.field.setNumber(2, "SizeMax", 200)
gmsh.model.mesh.field.setNumber(2, "DistMin", 4.0)
gmsh.model.mesh.field.setNumber(2, "DistMax", 8.0)

# reservoir interval
gmsh.model.mesh.field.add("Box", 3)
gmsh.model.mesh.field.setNumber(3, "VIn", 40) # 40
gmsh.model.mesh.field.setNumber(3, "VOut", 200)
gmsh.model.mesh.field.setNumber(3, "XMin", 0)
gmsh.model.mesh.field.setNumber(3, "XMax", 4000)
gmsh.model.mesh.field.setNumber(3, "YMin", 0)
gmsh.model.mesh.field.setNumber(3, "YMax", 4000)
gmsh.model.mesh.field.setNumber(3, "ZMin", -3100)
gmsh.model.mesh.field.setNumber(3, "ZMax", -2800)
# gmsh.model.mesh.field.setNumber(3, "Thickness", 100)

gmsh.model.mesh.field.add("Distance", 4)
gmsh.model.mesh.field.setNumbers(4, "FacesList", [109,110,22,64,42,84,45,87])
gmsh.model.mesh.field.setNumber(4, "Sampling", 1000)
gmsh.model.mesh.field.add("Threshold", 5)
gmsh.model.mesh.field.setNumber(5, "InField", 4)
gmsh.model.mesh.field.setNumber(5, "SizeMin", 40) # 40
gmsh.model.mesh.field.setNumber(5, "SizeMax", 200)
gmsh.model.mesh.field.setNumber(5, "DistMin", 1.0)
gmsh.model.mesh.field.setNumber(5, "DistMax", 1000.0)

# gmsh.model.mesh.field.setNumber(6, "Thickness", 0.3)

gmsh.model.mesh.field.add("Min", 7)
gmsh.model.mesh.field.setNumbers(7, "FieldsList", [2,3,5])

gmsh.model.mesh.field.setAsBackgroundMesh(7)

gmsh.option.setNumber("Mesh.MeshSizeExtendFromBoundary", 0)
gmsh.option.setNumber("Mesh.MeshSizeFromPoints", 0)
gmsh.option.setNumber("Mesh.MeshSizeFromCurvature", 0)

# Finally, while the default "Frontal-Delaunay" 2D meshing algorithm
# (Mesh.Algorithm = 6) usually leads to the highest quality meshes, the
# "Delaunay" algorithm (Mesh.Algorithm = 5) will handle complex mesh size fields
# better - in particular size fields with large element size gradients:

gmsh.option.setNumber("Mesh.Algorithm", 6)

gmsh.model.mesh.generate(3)
gmsh.write("Buijze3D_45.msh")
# Out:
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 5 (Line)
# Info    : [ 10%] Meshing curve 6 (Line)
# Info    : [ 10%] Meshing curve 7 (Line)
# Info    : [ 10%] Meshing curve 16 (Line)
# Info    : [ 10%] Meshing curve 30 (Line)
# Info    : [ 10%] Meshing curve 31 (Line)
# Info    : [ 10%] Meshing curve 34 (Line)
# Info    : [ 20%] Meshing curve 35 (Line)
# Info    : [ 20%] Meshing curve 52 (Line)
# Info    : [ 20%] Meshing curve 55 (Line)
# Info    : [ 20%] Meshing curve 56 (Line)
# Info    : [ 20%] Meshing curve 58 (Line)
# Info    : [ 20%] Meshing curve 59 (Line)
# Info    : [ 20%] Meshing curve 61 (Line)
# Info    : [ 20%] Meshing curve 65 (Line)
# Info    : [ 30%] Meshing curve 81 (Line)
# Info    : [ 30%] Meshing curve 82 (Line)
# Info    : [ 30%] Meshing curve 85 (Line)
# Info    : [ 30%] Meshing curve 86 (Line)
# Info    : [ 30%] Meshing curve 103 (Line)
# Info    : [ 30%] Meshing curve 106 (Line)
# Info    : [ 30%] Meshing curve 107 (Line)
# Info    : [ 30%] Meshing curve 109 (Line)
# Info    : [ 40%] Meshing curve 110 (Line)
# Info    : [ 40%] Meshing curve 112 (Line)
# Info    : [ 40%] Meshing curve 117 (Line)
# Info    : [ 40%] Meshing curve 118 (Line)
# Info    : [ 40%] Meshing curve 120 (Line)
# Info    : [ 40%] Meshing curve 122 (Line)
# Info    : [ 40%] Meshing curve 123 (Line)
# Info    : [ 40%] Meshing curve 124 (Line)
# Info    : [ 50%] Meshing curve 125 (Line)
# Info    : [ 50%] Meshing curve 126 (Line)
# Info    : [ 50%] Meshing curve 127 (Line)
# Info    : [ 50%] Meshing curve 128 (Line)
# Info    : [ 50%] Meshing curve 129 (Line)
# Info    : It. 83000 - 82952 nodes created - worst tet radius 1.01731 (nodes removed 0 48)
# Info    : It. 83500 - 83452 nodes created - worst tet radius 1.01536 (nodes removed 0 48)
# Info    : It. 84000 - 83951 nodes created - worst tet radius 1.01324 (nodes removed 0 49)
# Info    : It. 84500 - 84451 nodes created - worst tet radius 1.01121 (nodes removed 0 49)
# Info    : It. 85000 - 84951 nodes created - worst tet radius 1.00917 (nodes removed 0 49)
# Info    : It. 85500 - 85451 nodes created - worst tet radius 1.00706 (nodes removed 0 49)
# Info    : It. 86000 - 85951 nodes created - worst tet radius 1.00505 (nodes removed 0 49)
# Info    : It. 86500 - 86450 nodes created - worst tet radius 1.0032 (nodes removed 0 50)
# Info    : It. 87000 - 86948 nodes created - worst tet radius 1.00136 (nodes removed 0 52)
# Info    : 3D refinement terminated (268143 nodes total):
# Info    :  - 126 Delaunay cavities modified for star shapeness
# Info    :  - 52 nodes could not be inserted
# Info    :  - 1490385 tetrahedra created in 54.1443 sec. (27526 tets/s)
# Info    : Done meshing 3D (Wall 88.2955s, CPU 87.9878s)
# Info    : Optimizing mesh...
# Info    : Optimizing volume 27
# Info    : Optimization starts (volume = 9.56612e+09) with worst = 0.0052367 / average = 0.752036:
# Info    : 0.00 < quality < 0.10 :       206 elements
# Info    : 0.10 < quality < 0.20 :       490 elements
# Info    : 0.20 < quality < 0.30 :       802 elements
# Info    : 0.30 < quality < 0.40 :      1566 elements
# Info    : 0.40 < quality < 0.50 :      2740 elements
# Info    : 0.50 < quality < 0.60 :      4216 elements
# Info    : 0.60 < quality < 0.70 :      7834 elements
# Info    : 0.70 < quality < 0.80 :     17966 elements
# Info    : 0.80 < quality < 0.90 :     21691 elements
# Info    : 0.90 < quality < 1.00 :      9500 elements
# Info    : 1394 edge swaps, 31 node relocations (volume = 9.56612e+09): worst = 0.0436683 / average = 0.763926 (Wall 0.0834653s, CPU 0.084257s)
# Info    : 1431 edge swaps, 36 node relocations (volume = 9.56612e+09): worst = 0.18731 / average = 0.764106 (Wall 0.111734s, CPU 0.112959s)
# Info    : 1434 edge swaps, 36 node relocations (volume = 9.56612e+09): worst = 0.18731 / average = 0.764116 (Wall 0.140439s, CPU 0.142011s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         3 elements
# Info    : 0.20 < quality < 0.30 :        77 elements
# Info    : 0.30 < quality < 0.40 :      1597 elements
# Info    : 0.40 < quality < 0.50 :      2719 elements
# Info    : 0.50 < quality < 0.60 :      4202 elements
# Info    : 0.60 < quality < 0.70 :      7802 elements
# Info    : 0.70 < quality < 0.80 :     18105 elements
# Info    : 0.80 < quality < 0.90 :     21846 elements
# Info    : 0.90 < quality < 1.00 :      9443 elements
# Info    : Optimizing volume 28
# Info    : Optimization starts (volume = 2.41933e+09) with worst = 0.00767692 / average = 0.727365:
# Info    : 0.00 < quality < 0.10 :        79 elements
# Info    : 0.10 < quality < 0.20 :       196 elements
# Info    : 0.20 < quality < 0.30 :       423 elements
# Info    : 0.30 < quality < 0.40 :       774 elements
# Info    : 0.40 < quality < 0.50 :      1317 elements
# Info    : 0.50 < quality < 0.60 :      1900 elements
# Info    : 0.60 < quality < 0.70 :      3069 elements
# Info    : 0.70 < quality < 0.80 :      5987 elements
# Info    : 0.80 < quality < 0.90 :      6767 elements
# Info    : 0.90 < quality < 1.00 :      2860 elements
# Info    : 584 edge swaps, 10 node relocations (volume = 2.41933e+09): worst = 0.0833353 / average = 0.740054 (Wall 0.034235s, CPU 0.034569s)
# Info    : 606 edge swaps, 10 node relocations (volume = 2.41933e+09): worst = 0.167646 / average = 0.740254 (Wall 0.0418817s, CPU 0.042504s)
# Info    : 607 edge swaps, 10 node relocations (volume = 2.41933e+09): worst = 0.167646 / average = 0.740247 (Wall 0.0487571s, CPU 0.049708s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :         7 elements
# Info    : 0.20 < quality < 0.30 :        95 elements
# Info    : 0.30 < quality < 0.40 :       827 elements
# Info    : 0.40 < quality < 0.50 :      1323 elements
# Info    : 0.50 < quality < 0.60 :      1920 elements
# Info    : 0.60 < quality < 0.70 :      3044 elements
# Info    : 0.70 < quality < 0.80 :      6026 elements
# Info    : 0.80 < quality < 0.90 :      6812 elements
# Info    : 0.90 < quality < 1.00 :      2852 elements
# Info    : Optimizing volume 35
# Info    : Optimization starts (volume = 1.91657e+09) with worst = 0.00722679 / average = 0.679647:
# Info    : 0.00 < quality < 0.10 :       161 elements
# Info    : 0.10 < quality < 0.20 :       424 elements
# Info    : 0.20 < quality < 0.30 :      1194 elements
# Info    : 0.30 < quality < 0.40 :      1952 elements
# Info    : 0.40 < quality < 0.50 :      2028 elements
# Info    : 0.50 < quality < 0.60 :      2315 elements
# Info    : 0.60 < quality < 0.70 :      3541 elements
# Info    : 0.70 < quality < 0.80 :      6082 elements
# Info    : 0.80 < quality < 0.90 :      6692 elements
# Info    : 0.90 < quality < 1.00 :      2931 elements
# Info    : 1048 edge swaps, 12 node relocations (volume = 1.91657e+09): worst = 0.138557 / average = 0.695348 (Wall 0.0649873s, CPU 0.065547s)
# Info    : 1114 edge swaps, 13 node relocations (volume = 1.91657e+09): worst = 0.144129 / average = 0.695481 (Wall 0.0879302s, CPU 0.088823s)
# Info    : 1123 edge swaps, 14 node relocations (volume = 1.91657e+09): worst = 0.144129 / average = 0.695525 (Wall 0.114937s, CPU 0.116159s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :        40 elements
# Info    : 0.20 < quality < 0.30 :       771 elements
# Info    : 0.30 < quality < 0.40 :      2072 elements
# Info    : 0.40 < quality < 0.50 :      2057 elements
# Info    : 0.50 < quality < 0.60 :      2396 elements
# Info    : 0.60 < quality < 0.70 :      3496 elements
# Info    : 0.70 < quality < 0.80 :      6070 elements
# Info    : 0.80 < quality < 0.90 :      6738 elements
# Info    : 0.90 < quality < 1.00 :      2914 elements
# Info    : Optimizing volume 36
# Info    : Optimization starts (volume = 3.70913e+08) with worst = 0 / average = 0.46346:
# Info    : 0.00 < quality < 0.10 :      1256 elements
# Info    : 0.10 < quality < 0.20 :      4531 elements
# Info    : 0.20 < quality < 0.30 :     44622 elements
# Info    : 0.30 < quality < 0.40 :     90063 elements
# Info    : 0.40 < quality < 0.50 :     31183 elements
# Info    : 0.50 < quality < 0.60 :     13627 elements
# Info    : 0.60 < quality < 0.70 :     15602 elements
# Info    : 0.70 < quality < 0.80 :     19172 elements
# Info    : 0.80 < quality < 0.90 :     20285 elements
# Info    : 0.90 < quality < 1.00 :     10164 elements
# Info    : 11581 edge swaps, 3283 node relocations (volume = 3.70913e+08): worst = 0.0624538 / average = 0.476835 (Wall 2.49613s, CPU 2.49628s)
# Info    : 13871 edge swaps, 5518 node relocations (volume = 3.70913e+08): worst = 0.0703261 / average = 0.477778 (Wall 4.73575s, CPU 4.73621s)
# Info    : 14554 edge swaps, 6780 node relocations (volume = 3.70913e+08): worst = 0.0728344 / average = 0.478022 (Wall 6.89726s, CPU 6.89816s)
# Info    : 14733 edge swaps, 7584 node relocations (volume = 3.70913e+08): worst = 0.0728344 / average = 0.478052 (Wall 9.04653s, CPU 9.04786s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         3 elements
# Info    : 0.10 < quality < 0.20 :        83 elements
# Info    : 0.20 < quality < 0.30 :     37565 elements
# Info    : 0.30 < quality < 0.40 :     90134 elements
# Info    : 0.40 < quality < 0.50 :     35863 elements
# Info    : 0.50 < quality < 0.60 :     14023 elements
# Info    : 0.60 < quality < 0.70 :     15827 elements
# Info    : 0.70 < quality < 0.80 :     19240 elements
# Info    : 0.80 < quality < 0.90 :     20636 elements
# Info    : 0.90 < quality < 1.00 :     10050 elements
# Info    : Optimizing volume 37
# Info    : Optimization starts (volume = 5.76573e+09) with worst = 9.19192e-05 / average = 0.530745:
# Info    : 0.00 < quality < 0.10 :       482 elements
# Info    : 0.10 < quality < 0.20 :      1571 elements
# Info    : 0.20 < quality < 0.30 :     13291 elements
# Info    : 0.30 < quality < 0.40 :     23596 elements
# Info    : 0.40 < quality < 0.50 :     11104 elements
# Info    : 0.50 < quality < 0.60 :      7147 elements
# Info    : 0.60 < quality < 0.70 :      8493 elements
# Info    : 0.70 < quality < 0.80 :     11629 elements
# Info    : 0.80 < quality < 0.90 :     11621 elements
# Info    : 0.90 < quality < 1.00 :      5717 elements
# Info    : 3808 edge swaps, 702 node relocations (volume = 5.76573e+09): worst = 0.0582943 / average = 0.543759 (Wall 0.759803s, CPU 0.760518s)
# Info    : 4417 edge swaps, 1118 node relocations (volume = 5.76573e+09): worst = 0.0582943 / average = 0.544559 (Wall 1.42275s, CPU 1.42422s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         3 elements
# Info    : 0.10 < quality < 0.20 :       177 elements
# Info    : 0.20 < quality < 0.30 :     10519 elements
# Info    : 0.30 < quality < 0.40 :     23266 elements
# Info    : 0.40 < quality < 0.50 :     11745 elements
# Info    : 0.50 < quality < 0.60 :      7384 elements
# Info    : 0.60 < quality < 0.70 :      8443 elements
# Info    : 0.70 < quality < 0.80 :     11685 elements
# Info    : 0.80 < quality < 0.90 :     11666 elements
# Info    : 0.90 < quality < 1.00 :      5621 elements
# Info    : Optimizing volume 38
# Info    : Optimization starts (volume = 8.09446e+09) with worst = 0.00436869 / average = 0.649098:
# Info    : 0.00 < quality < 0.10 :       443 elements
# Info    : 0.10 < quality < 0.20 :      1269 elements
# Info    : 0.20 < quality < 0.30 :      7493 elements
# Info    : 0.30 < quality < 0.40 :     13449 elements
# Info    : 0.40 < quality < 0.50 :      7850 elements
# Info    : 0.50 < quality < 0.60 :      7028 elements
# Info    : 0.60 < quality < 0.70 :     10660 elements
# Info    : 0.70 < quality < 0.80 :     20063 elements
# Info    : 0.80 < quality < 0.90 :     24577 elements
# Info    : 0.90 < quality < 1.00 :     10795 elements
# Info    : 3165 edge swaps, 426 node relocations (volume = 8.09446e+09): worst = 0.0576606 / average = 0.661794 (Wall 0.451847s, CPU 0.453012s)
# Info    : 3577 edge swaps, 676 node relocations (volume = 8.09446e+09): worst = 0.107305 / average = 0.662399 (Wall 0.805167s, CPU 0.807147s)
# Info    : 3700 edge swaps, 853 node relocations (volume = 8.09446e+09): worst = 0.107305 / average = 0.662574 (Wall 1.15616s, CPU 1.15889s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :       104 elements
# Info    : 0.20 < quality < 0.30 :      5652 elements
# Info    : 0.30 < quality < 0.40 :     13518 elements
# Info    : 0.40 < quality < 0.50 :      8368 elements
# Info    : 0.50 < quality < 0.60 :      7109 elements
# Info    : 0.60 < quality < 0.70 :     10680 elements
# Info    : 0.70 < quality < 0.80 :     20191 elements
# Info    : 0.80 < quality < 0.90 :     24713 elements
# Info    : 0.90 < quality < 1.00 :     10713 elements
# Info    : Optimizing volume 39
# Info    : Optimization starts (volume = 1.17277e+09) with worst = 0.0040652 / average = 0.518742:
# Info    : 0.00 < quality < 0.10 :      1412 elements
# Info    : 0.10 < quality < 0.20 :      5094 elements
# Info    : 0.20 < quality < 0.30 :     46879 elements
# Info    : 0.30 < quality < 0.40 :     96015 elements
# Info    : 0.40 < quality < 0.50 :     34871 elements
# Info    : 0.50 < quality < 0.60 :     16481 elements
# Info    : 0.60 < quality < 0.70 :     21918 elements
# Info    : 0.70 < quality < 0.80 :     34349 elements
# Info    : 0.80 < quality < 0.90 :     42253 elements
# Info    : 0.90 < quality < 1.00 :     20169 elements
# Info    : 13202 edge swaps, 3756 node relocations (volume = 1.17277e+09): worst = 0.0568216 / average = 0.532407 (Wall 2.59873s, CPU 2.59913s)
# Info    : 15691 edge swaps, 5967 node relocations (volume = 1.17277e+09): worst = 0.130353 / average = 0.533105 (Wall 4.90006s, CPU 4.90091s)
# Info    : 16424 edge swaps, 7556 node relocations (volume = 1.17277e+09): worst = 0.144804 / average = 0.533261 (Wall 7.17466s, CPU 7.17582s)
# Info    : 16608 edge swaps, 8530 node relocations (volume = 1.17277e+09): worst = 0.144804 / average = 0.533299 (Wall 9.46948s, CPU 9.47103s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :        61 elements
# Info    : 0.20 < quality < 0.30 :     38969 elements
# Info    : 0.30 < quality < 0.40 :     95918 elements
# Info    : 0.40 < quality < 0.50 :     39949 elements
# Info    : 0.50 < quality < 0.60 :     16746 elements
# Info    : 0.60 < quality < 0.70 :     21945 elements
# Info    : 0.70 < quality < 0.80 :     34688 elements
# Info    : 0.80 < quality < 0.90 :     42707 elements
# Info    : 0.90 < quality < 1.00 :     20096 elements
# Info    : Optimizing volume 40
# Info    : Optimization starts (volume = 1.30796e+10) with worst = 0.00124257 / average = 0.656985:
# Info    : 0.00 < quality < 0.10 :       452 elements
# Info    : 0.10 < quality < 0.20 :      1314 elements
# Info    : 0.20 < quality < 0.30 :      7706 elements
# Info    : 0.30 < quality < 0.40 :     12476 elements
# Info    : 0.40 < quality < 0.50 :      7817 elements
# Info    : 0.50 < quality < 0.60 :      6549 elements
# Info    : 0.60 < quality < 0.70 :     10859 elements
# Info    : 0.70 < quality < 0.80 :     20945 elements
# Info    : 0.80 < quality < 0.90 :     25922 elements
# Info    : 0.90 < quality < 1.00 :     11588 elements
# Info    : 3160 edge swaps, 347 node relocations (volume = 1.30796e+10): worst = 0.0479425 / average = 0.670132 (Wall 0.477452s, CPU 0.47829s)
# Info    : 3475 edge swaps, 585 node relocations (volume = 1.30796e+10): worst = 0.135931 / average = 0.670349 (Wall 0.82306s, CPU 0.824716s)
# Info    : 3570 edge swaps, 709 node relocations (volume = 1.30796e+10): worst = 0.135931 / average = 0.670469 (Wall 1.15347s, CPU 1.15597s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :        98 elements
# Info    : 0.20 < quality < 0.30 :      5863 elements
# Info    : 0.30 < quality < 0.40 :     12696 elements
# Info    : 0.40 < quality < 0.50 :      8307 elements
# Info    : 0.50 < quality < 0.60 :      6677 elements
# Info    : 0.60 < quality < 0.70 :     10792 elements
# Info    : 0.70 < quality < 0.80 :     21050 elements
# Info    : 0.80 < quality < 0.90 :     26113 elements
# Info    : 0.90 < quality < 1.00 :     11531 elements
# Info    : Optimizing volume 41
# Info    : Optimization starts (volume = 1.15631e+10) with worst = 0.00605669 / average = 0.681239:
# Info    : 0.00 < quality < 0.10 :       354 elements
# Info    : 0.10 < quality < 0.20 :      1120 elements
# Info    : 0.20 < quality < 0.30 :      6256 elements
# Info    : 0.30 < quality < 0.40 :     11728 elements
# Info    : 0.40 < quality < 0.50 :      7033 elements
# Info    : 0.50 < quality < 0.60 :      6647 elements
# Info    : 0.60 < quality < 0.70 :     11778 elements
# Info    : 0.70 < quality < 0.80 :     22608 elements
# Info    : 0.80 < quality < 0.90 :     29558 elements
# Info    : 0.90 < quality < 1.00 :     13918 elements
# Info    : 2987 edge swaps, 355 node relocations (volume = 1.15631e+10): worst = 0.0450735 / average = 0.694013 (Wall 0.363371s, CPU 0.364182s)
# Info    : 3235 edge swaps, 515 node relocations (volume = 1.15631e+10): worst = 0.0726321 / average = 0.694292 (Wall 0.6448s, CPU 0.646492s)
# Info    : 3306 edge swaps, 615 node relocations (volume = 1.15631e+10): worst = 0.0726321 / average = 0.694347 (Wall 0.917511s, CPU 0.920156s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         1 elements
# Info    : 0.10 < quality < 0.20 :        40 elements
# Info    : 0.20 < quality < 0.30 :      4481 elements
# Info    : 0.30 < quality < 0.40 :     11751 elements
# Info    : 0.40 < quality < 0.50 :      7453 elements
# Info    : 0.50 < quality < 0.60 :      6694 elements
# Info    : 0.60 < quality < 0.70 :     11684 elements
# Info    : 0.70 < quality < 0.80 :     22876 elements
# Info    : 0.80 < quality < 0.90 :     29754 elements
# Info    : 0.90 < quality < 1.00 :     13847 elements
# Info    : Optimizing volume 42
# Info    : Optimization starts (volume = 1.21754e+09) with worst = 0 / average = 0.590867:
# Info    : 0.00 < quality < 0.10 :       775 elements
# Info    : 0.10 < quality < 0.20 :      2472 elements
# Info    : 0.20 < quality < 0.30 :     20749 elements
# Info    : 0.30 < quality < 0.40 :     42407 elements
# Info    : 0.40 < quality < 0.50 :     16692 elements
# Info    : 0.50 < quality < 0.60 :      9646 elements
# Info    : 0.60 < quality < 0.70 :     14842 elements
# Info    : 0.70 < quality < 0.80 :     28145 elements
# Info    : 0.80 < quality < 0.90 :     38319 elements
# Info    : 0.90 < quality < 1.00 :     17705 elements
# Info    : 6687 edge swaps, 1620 node relocations (volume = 1.21754e+09): worst = 0.055667 / average = 0.604161 (Wall 1.09222s, CPU 1.09282s)
# Info    : 7783 edge swaps, 2686 node relocations (volume = 1.21754e+09): worst = 0.067375 / average = 0.60466 (Wall 2.06072s, CPU 2.06191s)
# Info    : 8092 edge swaps, 3258 node relocations (volume = 1.21754e+09): worst = 0.067375 / average = 0.604814 (Wall 3.02832s, CPU 3.02997s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         3 elements
# Info    : 0.10 < quality < 0.20 :        36 elements
# Info    : 0.20 < quality < 0.30 :     16588 elements
# Info    : 0.30 < quality < 0.40 :     42225 elements
# Info    : 0.40 < quality < 0.50 :     18401 elements
# Info    : 0.50 < quality < 0.60 :      9746 elements
# Info    : 0.60 < quality < 0.70 :     14964 elements
# Info    : 0.70 < quality < 0.80 :     28378 elements
# Info    : 0.80 < quality < 0.90 :     38601 elements
# Info    : 0.90 < quality < 1.00 :     17586 elements
# Info    : Optimizing volume 43
# Info    : Optimization starts (volume = 5.21581e+09) with worst = 0.000935897 / average = 0.593283:
# Info    : 0.00 < quality < 0.10 :       292 elements
# Info    : 0.10 < quality < 0.20 :       913 elements
# Info    : 0.20 < quality < 0.30 :      6707 elements
# Info    : 0.30 < quality < 0.40 :     11579 elements
# Info    : 0.40 < quality < 0.50 :      5856 elements
# Info    : 0.50 < quality < 0.60 :      4259 elements
# Info    : 0.60 < quality < 0.70 :      6073 elements
# Info    : 0.70 < quality < 0.80 :     10093 elements
# Info    : 0.80 < quality < 0.90 :     11396 elements
# Info    : 0.90 < quality < 1.00 :      5247 elements
# Info    : 2260 edge swaps, 423 node relocations (volume = 5.21581e+09): worst = 0.0914403 / average = 0.607726 (Wall 0.395329s, CPU 0.396581s)
# Info    : 2605 edge swaps, 658 node relocations (volume = 5.21581e+09): worst = 0.120446 / average = 0.608225 (Wall 0.693632s, CPU 0.695642s)
# Info    : 2688 edge swaps, 744 node relocations (volume = 5.21581e+09): worst = 0.120446 / average = 0.608362 (Wall 1.01232s, CPU 1.01515s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         0 elements
# Info    : 0.10 < quality < 0.20 :        65 elements
# Info    : 0.20 < quality < 0.30 :      5193 elements
# Info    : 0.30 < quality < 0.40 :     11551 elements
# Info    : 0.40 < quality < 0.50 :      6626 elements
# Info    : 0.50 < quality < 0.60 :      4418 elements
# Info    : 0.60 < quality < 0.70 :      5977 elements
# Info    : 0.70 < quality < 0.80 :     10103 elements
# Info    : 0.80 < quality < 0.90 :     11520 elements
# Info    : 0.90 < quality < 1.00 :      5210 elements
# Info    : Optimizing volume 44
# Info    : Optimization starts (volume = 4.18073e+08) with worst = 0.000388148 / average = 0.501922:
# Info    : 0.00 < quality < 0.10 :       568 elements
# Info    : 0.10 < quality < 0.20 :      2231 elements
# Info    : 0.20 < quality < 0.30 :     21306 elements
# Info    : 0.30 < quality < 0.40 :     42710 elements
# Info    : 0.40 < quality < 0.50 :     15291 elements
# Info    : 0.50 < quality < 0.60 :      6454 elements
# Info    : 0.60 < quality < 0.70 :      8467 elements
# Info    : 0.70 < quality < 0.80 :     12817 elements
# Info    : 0.80 < quality < 0.90 :     15974 elements
# Info    : 0.90 < quality < 1.00 :      7844 elements
# Info    : 5608 edge swaps, 1740 node relocations (volume = 4.18073e+08): worst = 0.0542984 / average = 0.515193 (Wall 1.12106s, CPU 1.1214s)
# Info    : 6800 edge swaps, 2871 node relocations (volume = 4.18073e+08): worst = 0.0564328 / average = 0.51596 (Wall 2.14231s, CPU 2.14286s)
# Info    : 7142 edge swaps, 3547 node relocations (volume = 4.18073e+08): worst = 0.0564328 / average = 0.51621 (Wall 3.16706s, CPU 3.16801s)
# Info    : No ill-shaped tets in the mesh :-)
# Info    : 0.00 < quality < 0.10 :         1 elements
# Info    : 0.10 < quality < 0.20 :        26 elements
# Info    : 0.20 < quality < 0.30 :     17729 elements
# Info    : 0.30 < quality < 0.40 :     42437 elements
# Info    : 0.40 < quality < 0.50 :     17290 elements
# Info    : 0.50 < quality < 0.60 :      6634 elements
# Info    : 0.60 < quality < 0.70 :      8388 elements
# Info    : 0.70 < quality < 0.80 :     12928 elements
# Info    : 0.80 < quality < 0.90 :     16151 elements
# Info    : 0.90 < quality < 1.00 :      7800 elements
# Info    : Done optimizing mesh (Wall 34.8001s, CPU 34.756s)
# Info    : 268143 nodes 1834386 elements
# Info    : Writing 'Buijze3D_45.msh'...
# Info    : Done writing 'Buijze3D_45.msh'

# %%
gmsh.model.occ.synchronize()

if '-nopopup' not in sys.argv:
    gmsh.fltk.run()
gmsh.finalize()
# Out:
# -------------------------------------------------------
# Version       : 4.9.0
# License       : GNU General Public License
# Build OS      : Linux64-sdk
# Build date    : 20211203
# Build host    : gmsh.info
# Build options : 64Bit ALGLIB[contrib] ANN[contrib] Bamg Blas[petsc] Blossom Cgns DIntegration Dlopen DomHex Eigen[contrib] Fltk Gmm[contrib] Hxt Jpeg Kbipack Lapack[petsc] LinuxJoystick MathEx[contrib] Med Mesh Metis[contrib] Mmg Mpeg Netgen ONELAB ONELABMetamodel OpenCASCADE OpenCASCADE-CAF OpenGL OpenMP OptHom PETSc Parser Plugins Png Post QuadMeshingTools QuadTri Solver TetGen/BR Voro++[contrib] WinslowUntangler Zlib
# FLTK version  : 1.4.0
# PETSc version : 3.14.4 (real arithmtic)
# OCC version   : 7.6.0
# MED version   : 4.1.0
# Packaged by   : geuzaine
# Web site      : https://gmsh.info
# Issue tracker : https://gitlab.onelab.info/gmsh/gmsh/issues
# -------------------------------------------------------
